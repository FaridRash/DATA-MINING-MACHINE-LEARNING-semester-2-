# %% [markdown]
# #Libraries

# %%
import time
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from imutils import paths
from tensorflow import keras
import matplotlib.pyplot as plt
from collections import Counter
from tensorflow.nn import softmax 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, precision_score, recall_score
import seaborn as sns
import cv2
from skimage.metrics import structural_similarity as ssim
# Out:
# 2024-11-05 18:08:12.229054: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-11-05 18:08:13.695125: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-11-05 18:08:13.695951: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2024-11-05 18:08:13.710579: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 18:08:13.710715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: Quadro P2000 computeCapability: 6.1
# coreClock: 1.607GHz coreCount: 6 deviceMemorySize: 3.94GiB deviceMemoryBandwidth: 89.53GiB/s
# 2024-11-05 18:08:13.710737: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-11-05 18:08:13.712278: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-11-05 18:08:13.712316: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-11-05 18:08:13.713599: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-11-05 18:08:13.713917: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-11-05 18:08:13.715407: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-11-05 18:08:13.716210: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-11-05 18:08:13.719310: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-11-05 18:08:13.719558: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 18:08:13.719936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 18:08:13.720043: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %%
# Reading FRI Images
imagePaths = list(paths.list_images(r"/home/gunner/Dataset/FR0"))

data = []
data_cropped = []
labels = []
label = 0
counter_0 = 0

for imagePath in imagePaths:
  image = tf.io.read_file(imagePath)
  image = tf.image.decode_image(image, channels=1)
  data.append(image)
  labels.append(label)
  counter_0 += 1
print(f'Loaded FR0... {counter_0} files has loaded.')
# Out:
# 2024-11-05 18:08:13.743695: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-05 18:08:13.744500: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-11-05 18:08:13.744705: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 18:08:13.744842: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: Quadro P2000 computeCapability: 6.1
# coreClock: 1.607GHz coreCount: 6 deviceMemorySize: 3.94GiB deviceMemoryBandwidth: 89.53GiB/s
# 2024-11-05 18:08:13.744872: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-11-05 18:08:13.744910: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-11-05 18:08:13.744930: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-11-05 18:08:13.744949: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-11-05 18:08:13.744968: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-11-05 18:08:13.744987: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-11-05 18:08:13.745006: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-11-05 18:08:13.745026: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-11-05 18:08:13.745169: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 18:08:13.745317: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 18:08:13.745410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-11-05 18:08:13.745437: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-11-05 18:08:14.142884: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-11-05 18:08:14.142934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2024-11-05 18:08:14.142941: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2024-11-05 18:08:14.143144: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 18:08:14.143335: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 18:08:14.143477: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 18:08:14.143582: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3571 MB memory) -> physical GPU (device: 0, name: Quadro P2000, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Loaded FR0... 6066 files has loaded.

# %%
# Reading FRI Images
imagePaths = list(paths.list_images(r"/home/gunner/Dataset/FRI"))


label = 1
counter_1 = 0

for imagePath in imagePaths:
  image = tf.io.read_file(imagePath)
  image = tf.image.decode_image(image, channels=1)
  data.append(image)
  labels.append(label)
  counter_1 += 1
print(f'Loaded FRI... {counter_1} files has loaded.')
# Out:
# Loaded FRI... 5008 files has loaded.

# %%
# Reading FRI Images
imagePaths = list(paths.list_images(r"/home/gunner/Dataset/FRII"))

label = 2
counter_2 = 0

for imagePath in imagePaths:
  image = tf.io.read_file(imagePath)
  image = tf.image.decode_image(image, channels=1)
  data.append(image)
  labels.append(label)
  counter_2 += 1
print(f'Loaded FRII... {counter_2} files has loaded.')
# Out:
# Loaded FRII... 2066 files has loaded.

# %% [markdown]
# #**Cropping**

# %%
data_cropped = []
for image in data:
  image = tf.image.crop_to_bounding_box(image, 120, 120, 60, 60)
  data_cropped.append(image)

# %% [markdown]
# #**EDA**

# %%
counter = Counter(labels)
sorted_counts = dict(sorted(counter.items()))
plt.bar(sorted_counts.keys(), sorted_counts.values(), color='skyblue')
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Each Class in the Dataset')
plt.xticks(range(3))
plt.show()

# %%
labels = np.array(labels,dtype='uint8')
data = np.array(data,dtype='uint8')
data_cropped = np.array(data_cropped,dtype='uint8')

# %%
class_0 = data[labels == 0]
image = np.squeeze(class_0[1])
plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FR0")

class_1 = data[labels == 1]
image = np.squeeze(class_1[1])
plt.subplot(1, 3, 2)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRI")

class_2 = data[labels == 2]
image = np.squeeze(class_2[1])
plt.subplot(1, 3, 3)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRII")


plt.show()

# %%
class_0 = data_cropped[labels == 0]
image = np.squeeze(class_0[1])
plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FR0")

class_1 = data_cropped[labels == 1]
image = np.squeeze(class_1[1])
plt.subplot(1, 3, 2)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRI")

class_2 = data_cropped[labels == 2]
image = np.squeeze(class_2[1])
plt.subplot(1, 3, 3)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRII")


plt.show()

# %% [markdown]
# #**Filterring**

# %%
data_cropped.shape, labels.shape
# Out:
# ((13140, 60, 60, 1), (13140,))

# %%
mask = np.array([np.max(image) >= 5 for image in data_cropped])
filtered_data = data_cropped[mask]
filtered_labels = labels[mask]

# %%
mask_useless = np.array([np.max(image) < 5 for image in data_cropped])
useless_data = data_cropped[mask_useless]
useless_labels = labels[mask_useless]

# %%
class_0_useless = useless_data[useless_labels == 0]
class_1_useless = useless_data[useless_labels == 1]
class_2_useless = useless_data[useless_labels == 2]

# %%
np.max(class_0_useless), np.max(class_1_useless), np.max(class_2_useless)
# Out:
# (2, 0, 2)

# %%
class_0_useless.shape, class_1_useless.shape, class_2_useless.shape
# Out:
# ((94, 60, 60, 1), (40, 60, 60, 1), (36, 60, 60, 1))

# %%
temp = 0
for i in class_0_useless:
  if np.max(i) >temp:
    temp = np.max(i)
    image = np.squeeze(i)
plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FR0")

temp = 0
for i in class_1_useless:
  if np.max(i) >temp:
    temp = np.max(i)
    image = np.squeeze(i)
plt.subplot(1, 3, 2)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRI")

temp = 0
for i in class_2_useless:
  if np.max(i) >temp:
    temp = np.max(i)
    image = np.squeeze(i)
plt.subplot(1, 3, 3)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRII")


plt.show()

# %%
counter = Counter(filtered_labels)
sorted_counts = dict(sorted(counter.items()))
plt.bar(sorted_counts.keys(), sorted_counts.values(), color='skyblue')
plt.grid(True)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Each Class in the Dataset')
plt.xticks(range(3))
plt.show()

# %%
class_0_image = filtered_data[filtered_labels == 0]
class_1_image = filtered_data[filtered_labels == 1]
class_2_image = filtered_data[filtered_labels == 2]
class_0_image.shape, class_1_image.shape, class_2_image.shape
# Out:
# ((5972, 60, 60, 1), (4968, 60, 60, 1), (2030, 60, 60, 1))

# %% [markdown]
# #**Augmentation**

# %%
datagen = ImageDataGenerator(rotation_range=30,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             shear_range=0.2,
                             horizontal_flip=True,
                             fill_mode='nearest')
class_2_data = filtered_data[filtered_labels == 2]
class_1_data = filtered_data[filtered_labels == 1]


augmented_class_2_data = []
augmented_class_2_labels = []

for i in range(4000):
    image = class_2_data[np.random.randint(0, len(class_2_data))]
    augmented_image = datagen.random_transform(image)
    augmented_class_2_data.append(augmented_image)
    augmented_class_2_labels.append(2)



augmented_class_1_data = []
augmented_class_1_labels = []

for i in range(1000):
    image = class_1_data[np.random.randint(0, len(class_1_data))]
    augmented_image = datagen.random_transform(image)
    augmented_class_1_data.append(augmented_image)
    augmented_class_1_labels.append(1)

# %%
augmented_class_2_data = np.array(augmented_class_2_data)
augmented_class_2_labels = np.array(augmented_class_2_labels)

augmented_class_1_data = np.array(augmented_class_1_data)
augmented_class_1_labels = np.array(augmented_class_1_labels)

final_data = np.concatenate((filtered_data, augmented_class_2_data, augmented_class_1_data), axis=0)
final_labels = np.concatenate((filtered_labels, augmented_class_2_labels, augmented_class_1_labels), axis=0)

# %%
print("Final data shape:", final_data.shape)
print("Final labels shape:", final_labels.shape)
# Out:
# Final data shape: (17970, 60, 60, 1)
# Final labels shape: (17970,)

# %%
counter = Counter(final_labels)
sorted_counts = dict(sorted(counter.items()))
plt.bar(sorted_counts.keys(), sorted_counts.values(), color='skyblue')
plt.grid(True)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Each Class in the Dataset')
plt.xticks(range(3))
plt.show()

# %%
class_0_flatten = []
class_1_flatten = []
class_2_flatten = []


for image in final_data[final_labels == 0]:
    class_0_flatten.append(image.flatten())

for image in final_data[final_labels == 1]:
    class_1_flatten.append(image.flatten())

for image in final_data[final_labels == 2]:
    class_2_flatten.append(image.flatten())


class_0_flatten = np.array(class_0_flatten, dtype='uint8')
class_1_flatten = np.array(class_1_flatten, dtype='uint8')
class_2_flatten = np.array(class_2_flatten, dtype='uint8')

class_0_flatten.shape, class_1_flatten.shape, class_2_flatten.shape, final_data.shape, final_labels.shape
# Out:
# ((5972, 3600), (5968, 3600), (6030, 3600), (17970, 60, 60, 1), (17970,))

# %% [markdown]
# #**Flatten images**

# %%
for i in range(5):
    plt.plot(class_0_flatten[i], color='red')

plt.show();

# %%
for i in range(5):
    plt.plot(class_1_flatten[i], color='red')

plt.show();

# %%
for i in range(5):
    plt.plot(class_2_flatten[i], color='red')
    
plt.show();

# %% [markdown]
# #**Pixels mean**

# %%
class_0_mean = np.mean(class_0_flatten, axis=0)

plt.plot(class_0_mean)
plt.show()

# %%
class_1_mean = np.mean(class_1_flatten, axis=0)

plt.plot(class_1_mean)
plt.show()

# %%
class_2_mean = np.mean(class_2_flatten, axis=0)

plt.plot(class_2_mean)
plt.show()

# %% [markdown]
# #**Pixels Correlation**

# %%
correlation_matrix = np.corrcoef(class_0_flatten, rowvar=False)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Pixel Correlation Matrix Across All Classes")
plt.xlabel("Pixel Index")
plt.ylabel("Pixel Index")
plt.show()

# %%
correlation_matrix = np.corrcoef(class_1_flatten, rowvar=False)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Pixel Correlation Matrix Across All Classes")
plt.xlabel("Pixel Index")
plt.ylabel("Pixel Index")
plt.show()

# %%
correlation_matrix = np.corrcoef(class_2_flatten, rowvar=False)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Pixel Correlation Matrix Across All Classes")
plt.xlabel("Pixel Index")
plt.ylabel("Pixel Index")
plt.show()

# %% [markdown]
# #**Sobel**

# %%
class_0_image = final_data[final_labels == 0]
class_1_image = final_data[final_labels == 1]
class_2_image = final_data[final_labels == 2]

# %%
class_0_image.shape, class_1_image.shape, class_2_image.shape
# Out:
# ((5972, 60, 60, 1), (5968, 60, 60, 1), (6030, 60, 60, 1))

# %%
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)
edge_image = np.sqrt(sobel_x**2 + sobel_y**2)

plt.figure(figsize=(12, 6))
for i in range(3):
    image = class_0_image[i]
    sobel_x = cv2.Sobel(class_0_image[i], cv2.CV_64F, 1, 0, ksize=5)
    sobel_y = cv2.Sobel(class_0_image[i], cv2.CV_64F, 0, 1, ksize=5)   
    edge_image = np.sqrt(sobel_x**2 + sobel_y**2)
    plt.subplot(2, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"Original FR0 {i+1}")
    plt.axis('off')

    plt.subplot(2, 5, i+6)
    plt.imshow(edge_image, cmap='gray')
    plt.title(f"Sobel Edges FR0 {i+1}")
    plt.axis('off')

# %%
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)
edge_image = np.sqrt(sobel_x**2 + sobel_y**2)

plt.figure(figsize=(12, 6))
for i in range(3):
    image = class_1_image[i]
    sobel_x = cv2.Sobel(class_1_image[i], cv2.CV_64F, 1, 0, ksize=5)
    sobel_y = cv2.Sobel(class_1_image[i], cv2.CV_64F, 0, 1, ksize=5)   
    edge_image = np.sqrt(sobel_x**2 + sobel_y**2)
    plt.subplot(2, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"Original FRI {i+1}")
    plt.axis('off')

    plt.subplot(2, 5, i+6)
    plt.imshow(edge_image, cmap='gray')
    plt.title(f"Sobel Edges FRI {i+1}")
    plt.axis('off')

# %%
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)
edge_image = np.sqrt(sobel_x**2 + sobel_y**2)

plt.figure(figsize=(12, 6))
for i in range(1, 4):
    image = class_2_image[i]
    sobel_x = cv2.Sobel(class_2_image[i], cv2.CV_64F, 1, 0, ksize=5)
    sobel_y = cv2.Sobel(class_2_image[i], cv2.CV_64F, 0, 1, ksize=5)   
    edge_image = np.sqrt(sobel_x**2 + sobel_y**2)
    plt.subplot(2, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"Original FRII {i+1}")
    plt.axis('off')

    plt.subplot(2, 5, i+6)
    plt.imshow(edge_image, cmap='gray')
    plt.title(f"Sobel Edges FRII {i+1}")
    plt.axis('off')

# %% [markdown]
# #**Symmetry**

# %%
plt.figure(figsize=(12, 6))
for i in range(3):
    image = class_0_image[i]
    image = cv2.resize(image, (50, 50))  

    flipped_image = cv2.flip(image, 1)

    symmetry_score, _ = ssim(image, flipped_image, full=True)


    # Original Image
    plt.subplot(3, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"FR0 {i+1}")
    plt.axis('off')

    # Flipped Image
    flipped_image = cv2.flip(image, 1)
    plt.subplot(3, 5, i+6)
    plt.imshow(flipped_image, cmap='gray')
    plt.title(f"Flipped FR0 {i+1}")
    plt.axis('off')

    # Symmetry Score
    plt.subplot(3, 5, i+11)
    plt.text(0.5, 0.5, f"SSIM: {symmetry_score:.2f}", ha='center', va='center', fontsize=12)
    plt.axis('off')

# %%
plt.figure(figsize=(12, 6))
for i in range(3):
    image = class_1_image[i]
    image = cv2.resize(image, (50, 50))  

    flipped_image = cv2.flip(image, 1)

    symmetry_score, _ = ssim(image, flipped_image, full=True)


    # Original Image
    plt.subplot(3, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"FRI {i+1}")
    plt.axis('off')

    # Flipped Image
    flipped_image = cv2.flip(image, 1)
    plt.subplot(3, 5, i+6)
    plt.imshow(flipped_image, cmap='gray')
    plt.title(f"Flipped FRI {i+1}")
    plt.axis('off')

    # Symmetry Score
    plt.subplot(3, 5, i+11)
    plt.text(0.5, 0.5, f"SSIM: {symmetry_score:.2f}", ha='center', va='center', fontsize=12)
    plt.axis('off')

# %%
plt.figure(figsize=(12, 6))
for i in range(1, 4):
    image = class_2_image[i]
    image = cv2.resize(image, (50, 50))  

    flipped_image = cv2.flip(image, 1)

    symmetry_score, _ = ssim(image, flipped_image, full=True)


    # Original Image
    plt.subplot(3, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"FRII {i+1}")
    plt.axis('off')

    # Flipped Image
    flipped_image = cv2.flip(image, 1)
    plt.subplot(3, 5, i+6)
    plt.imshow(flipped_image, cmap='gray')
    plt.title(f"Flipped FRII {i+1}")
    plt.axis('off')

    # Symmetry Score
    plt.subplot(3, 5, i+11)
    plt.text(0.5, 0.5, f"SSIM: {symmetry_score:.2f}", ha='center', va='center', fontsize=12)
    plt.axis('off')

# %%
flipped_class_0_scores = []

for i in class_0_image:
    image = cv2.resize(i, (50, 50))  
    flipped_image = cv2.flip(image, 1)
    symmetry_score, _ = ssim(image, flipped_image, full=True)
    flipped_class_0_scores.append(symmetry_score)

flipped_class_0_scores = np.array(flipped_class_0_scores)
flipped_class_0_scores_mean = np.mean(flipped_class_0_scores)
flipped_class_0_scores.shape
# Out:
# (5972,)

# %%
flipped_class_1_scores = []

for i in class_1_image:
    image = cv2.resize(i, (50, 50))  
    flipped_image = cv2.flip(image, 1)
    symmetry_score, _ = ssim(image, flipped_image, full=True)
    flipped_class_1_scores.append(symmetry_score)

flipped_class_1_scores = np.array(flipped_class_1_scores)
flipped_class_1_scores_mean = np.mean(flipped_class_1_scores)
flipped_class_1_scores.shape
# Out:
# (5968,)

# %%
flipped_class_2_scores = []

for i in class_2_image:
    image = cv2.resize(i, (50, 50))  
    flipped_image = cv2.flip(image, 1)
    symmetry_score, _ = ssim(image, flipped_image, full=True)
    flipped_class_2_scores.append(symmetry_score)

flipped_class_2_scores = np.array(flipped_class_2_scores)
flipped_class_2_scores_mean = np.mean(flipped_class_2_scores)
flipped_class_2_scores.shape
# Out:
# (6030,)

# %%
print(f'FR0 numbers: {flipped_class_0_scores.shape} , FRI Numbers: {flipped_class_1_scores.shape}, FRII Numbers: {flipped_class_2_scores.shape}')
print(f'FR0 Symmetry Score: {flipped_class_0_scores_mean:0.2f} , FRI Symmetry Score: {flipped_class_1_scores_mean:0.2f}, FRII Symmetry Score: {flipped_class_2_scores_mean:0.2f}')


flipped_labels = ['FR0', 'FRI', 'FRII']
flipped_values = [flipped_class_0_scores_mean, flipped_class_1_scores_mean, flipped_class_2_scores_mean]
plt.bar(flipped_labels, flipped_values)
plt.show()
# Out:
# FR0 numbers: (5972,) , FRI Numbers: (5968,), FRII Numbers: (6030,)
# FR0 Symmetry Score: 0.95 , FRI Symmetry Score: 0.82, FRII Symmetry Score: 0.70

# %%
flipped_scores = []

for i in final_data:
    image = cv2.resize(i, (50, 50))  
    flipped_image = cv2.flip(image, 1)
    symmetry_score, _ = ssim(image, flipped_image, full=True)
    flipped_scores.append(symmetry_score)

flipped_scores = np.array(flipped_scores)
flipped_scores_mean = np.mean(flipped_scores)
flipped_scores.shape
# Out:
# (17970,)

# %%
flipped_scores.shape
# Out:
# (17970,)

# %% [markdown]
# #**Preprocessing**

# %%
np.min(final_data[0]), np.max(final_data[0])
# Out:
# (0, 251)

# %%
data_normalized = final_data / 255

# %%
print(f'Min of original = {np.min(final_data[0])}')
print(f'Max of original = {np.max(final_data[0])}')
print(f'Min of original = {np.min(data_normalized[0])}')
print(f'Max of original = {np.max(data_normalized[0])}')
# Out:
# Min of original = 0
# Max of original = 251
# Min of original = 0.0
# Max of original = 0.984313725490196

# %%
cropped_flat = final_data.flatten()
normalized_flat = data_normalized.flatten()

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.boxplot(cropped_flat)
plt.title("Original Pixel Values (0-255)")
plt.ylabel("Pixel Intensity")

plt.subplot(1, 2, 2)
plt.boxplot(normalized_flat)
plt.title("Normalized Pixel Values (0-1)")
plt.ylabel("Pixel Intensity")

plt.tight_layout()
plt.show()

# %% [markdown]
# #***An explanation about the data frames***
#
# #**data_cropped -->> filtered_data -->> final_data -->> data_normalized**
#
# #**labels -->> filtered_labels -->> final_labels**

# %% [markdown]
# #**Splitting**

# %%
x = data_normalized
y = final_labels
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((12579, 60, 60, 1), (12579,), (5391, 60, 60, 1), (5391,))

# %% [markdown]
# #**CNN**

# %%
model_cnn = keras.Sequential()

#Seed
tf.random.set_seed(42)

#CNN
model_cnn.add(keras.layers.Conv2D(8, kernel_size=(3,3), input_shape=(60, 60, 1)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))

model_cnn.add(keras.layers.Conv2D(16, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))
model_cnn.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model_cnn.add(keras.layers.Conv2D(32, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))
model_cnn.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model_cnn.add(keras.layers.Conv2D(64, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))
model_cnn.add(keras.layers.MaxPool2D(pool_size=(2, 2)))

model_cnn.add(keras.layers.Conv2D(64, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))
model_cnn.add(keras.layers.MaxPool2D(pool_size=(2, 2)))


#Dense
model_cnn.add(keras.layers.Flatten())
model_cnn.add(keras.layers.Dense(units=64, activation='relu'))
model_cnn.add(keras.layers.Dropout(0.5))



#Output
model_cnn.add(keras.layers.Dense(units=3, activation=keras.activations.softmax))


#Model Compiling
optimizer = keras.optimizers.Adam(learning_rate=0.00002)
loss = keras.losses.SparseCategoricalCrossentropy()
metric = [keras.metrics.CategoricalAccuracy()]

model_cnn.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])


#Builing and Summury
model_cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 58, 58, 8)         80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 58, 58, 8)         32
# _________________________________________________________________
# activation (Activation)      (None, 58, 58, 8)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 56, 56, 16)        1168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 56, 56, 16)        64
# _________________________________________________________________
# activation_1 (Activation)    (None, 56, 56, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 32)        4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 26, 26, 32)        128
# _________________________________________________________________
# activation_2 (Activation)    (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 11, 11, 64)        256
# _________________________________________________________________
# activation_3 (Activation)    (None, 11, 11, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 3, 3, 64)          256
# _________________________________________________________________
# activation_4 (Activation)    (None, 3, 3, 64)          0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 66,403
# Trainable params: 66,035
# Non-trainable params: 368
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

# %%
start = time.perf_counter()
hist = model_cnn.fit(x_train, y_train, batch_size=512, epochs=100, validation_data=(x_test, y_test), callbacks=[early_stopping])
end = time.perf_counter()
# Out:
# Epoch 1/100
# 2024-11-05 18:09:17.525893: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2024-11-05 18:09:17.526194: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2599990000 Hz
# 2024-11-05 18:09:18.001448: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-11-05 18:09:18.088857: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-11-05 18:09:18.663064: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2024-11-05 18:09:18.779226: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 25/25 [==============================] - 33s 855ms/step - loss: 1.6084 - accuracy: 0.3569 - val_loss: 1.1014 - val_accuracy: 0.3365
# Epoch 2/100
# 25/25 [==============================] - 3s 128ms/step - loss: 1.2963 - accuracy: 0.4188 - val_loss: 1.1066 - val_accuracy: 0.3365
# Epoch 3/100
# 25/25 [==============================] - 3s 127ms/step - loss: 1.1472 - accuracy: 0.4749 - val_loss: 1.1105 - val_accuracy: 0.3367
# Epoch 4/100
# 25/25 [==============================] - 3s 127ms/step - loss: 1.0449 - accuracy: 0.5136 - val_loss: 1.1128 - val_accuracy: 0.3331
# Epoch 5/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.9947 - accuracy: 0.5326 - val_loss: 1.1145 - val_accuracy: 0.3363
# Epoch 6/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.9454 - accuracy: 0.5693 - val_loss: 1.1157 - val_accuracy: 0.3363
# Epoch 7/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.9044 - accuracy: 0.5821 - val_loss: 1.1164 - val_accuracy: 0.3363
# Epoch 8/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.8690 - accuracy: 0.5948 - val_loss: 1.1166 - val_accuracy: 0.3363
# Epoch 9/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.8272 - accuracy: 0.6269 - val_loss: 1.1111 - val_accuracy: 0.3363
# Epoch 10/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.7911 - accuracy: 0.6380 - val_loss: 1.0971 - val_accuracy: 0.3367
# Epoch 11/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.7721 - accuracy: 0.6531 - val_loss: 1.0793 - val_accuracy: 0.3378
# Epoch 12/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.7531 - accuracy: 0.6652 - val_loss: 1.0528 - val_accuracy: 0.3508
# Epoch 13/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.7427 - accuracy: 0.6644 - val_loss: 1.0133 - val_accuracy: 0.3990
# Epoch 14/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.7453 - accuracy: 0.6691 - val_loss: 0.9713 - val_accuracy: 0.5650
# Epoch 15/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.7136 - accuracy: 0.6866 - val_loss: 0.9237 - val_accuracy: 0.6340
# Epoch 16/100
# 25/25 [==============================] - 3s 129ms/step - loss: 0.7140 - accuracy: 0.6871 - val_loss: 0.8757 - val_accuracy: 0.6795
# Epoch 17/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.7027 - accuracy: 0.6968 - val_loss: 0.8332 - val_accuracy: 0.7090
# Epoch 18/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6948 - accuracy: 0.7005 - val_loss: 0.7922 - val_accuracy: 0.7242
# Epoch 19/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.6888 - accuracy: 0.7031 - val_loss: 0.7527 - val_accuracy: 0.7385
# Epoch 20/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.6649 - accuracy: 0.7160 - val_loss: 0.7174 - val_accuracy: 0.7468
# Epoch 21/100
# 25/25 [==============================] - 3s 126ms/step - loss: 0.6744 - accuracy: 0.7077 - val_loss: 0.6846 - val_accuracy: 0.7561
# Epoch 22/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6665 - accuracy: 0.7211 - val_loss: 0.6563 - val_accuracy: 0.7596
# Epoch 23/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6613 - accuracy: 0.7192 - val_loss: 0.6357 - val_accuracy: 0.7648
# Epoch 24/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6556 - accuracy: 0.7228 - val_loss: 0.6163 - val_accuracy: 0.7692
# Epoch 25/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6452 - accuracy: 0.7230 - val_loss: 0.5985 - val_accuracy: 0.7743
# Epoch 26/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6356 - accuracy: 0.7308 - val_loss: 0.5846 - val_accuracy: 0.7772
# Epoch 27/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6327 - accuracy: 0.7376 - val_loss: 0.5735 - val_accuracy: 0.7783
# Epoch 28/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6359 - accuracy: 0.7326 - val_loss: 0.5657 - val_accuracy: 0.7789
# Epoch 29/100
# 25/25 [==============================] - 3s 126ms/step - loss: 0.6202 - accuracy: 0.7464 - val_loss: 0.5591 - val_accuracy: 0.7802
# Epoch 30/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6246 - accuracy: 0.7421 - val_loss: 0.5540 - val_accuracy: 0.7813
# Epoch 31/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6152 - accuracy: 0.7458 - val_loss: 0.5503 - val_accuracy: 0.7833
# Epoch 32/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6178 - accuracy: 0.7390 - val_loss: 0.5469 - val_accuracy: 0.7833
# Epoch 33/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6091 - accuracy: 0.7496 - val_loss: 0.5450 - val_accuracy: 0.7833
# Epoch 34/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6033 - accuracy: 0.7512 - val_loss: 0.5433 - val_accuracy: 0.7850
# Epoch 35/100
# 25/25 [==============================] - 3s 129ms/step - loss: 0.5928 - accuracy: 0.7515 - val_loss: 0.5417 - val_accuracy: 0.7846
# Epoch 36/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5935 - accuracy: 0.7528 - val_loss: 0.5397 - val_accuracy: 0.7850
# Epoch 37/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.6032 - accuracy: 0.7476 - val_loss: 0.5382 - val_accuracy: 0.7861
# Epoch 38/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5930 - accuracy: 0.7524 - val_loss: 0.5361 - val_accuracy: 0.7859
# Epoch 39/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5847 - accuracy: 0.7617 - val_loss: 0.5356 - val_accuracy: 0.7859
# Epoch 40/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5866 - accuracy: 0.7615 - val_loss: 0.5315 - val_accuracy: 0.7896
# Epoch 41/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5901 - accuracy: 0.7611 - val_loss: 0.5326 - val_accuracy: 0.7871
# Epoch 42/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5735 - accuracy: 0.7680 - val_loss: 0.5307 - val_accuracy: 0.7882
# Epoch 43/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5625 - accuracy: 0.7761 - val_loss: 0.5285 - val_accuracy: 0.7893
# Epoch 44/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5761 - accuracy: 0.7636 - val_loss: 0.5276 - val_accuracy: 0.7898
# Epoch 45/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5783 - accuracy: 0.7647 - val_loss: 0.5262 - val_accuracy: 0.7917
# Epoch 46/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5758 - accuracy: 0.7705 - val_loss: 0.5252 - val_accuracy: 0.7926
# Epoch 47/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5645 - accuracy: 0.7700 - val_loss: 0.5237 - val_accuracy: 0.7915
# Epoch 48/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5654 - accuracy: 0.7743 - val_loss: 0.5209 - val_accuracy: 0.7948
# Epoch 49/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5661 - accuracy: 0.7685 - val_loss: 0.5213 - val_accuracy: 0.7948
# Epoch 50/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5574 - accuracy: 0.7775 - val_loss: 0.5186 - val_accuracy: 0.7963
# Epoch 51/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5591 - accuracy: 0.7672 - val_loss: 0.5200 - val_accuracy: 0.7950
# Epoch 52/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5396 - accuracy: 0.7816 - val_loss: 0.5172 - val_accuracy: 0.7967
# Epoch 53/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5399 - accuracy: 0.7865 - val_loss: 0.5155 - val_accuracy: 0.7974
# Epoch 54/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5469 - accuracy: 0.7839 - val_loss: 0.5165 - val_accuracy: 0.7973
# Epoch 55/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5442 - accuracy: 0.7840 - val_loss: 0.5134 - val_accuracy: 0.7980
# Epoch 56/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5413 - accuracy: 0.7870 - val_loss: 0.5134 - val_accuracy: 0.7991
# Epoch 57/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5381 - accuracy: 0.7854 - val_loss: 0.5123 - val_accuracy: 0.7997
# Epoch 58/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5514 - accuracy: 0.7797 - val_loss: 0.5117 - val_accuracy: 0.7997
# Epoch 59/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5309 - accuracy: 0.7919 - val_loss: 0.5107 - val_accuracy: 0.8000
# Epoch 60/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5248 - accuracy: 0.7937 - val_loss: 0.5104 - val_accuracy: 0.7999
# Epoch 61/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5296 - accuracy: 0.7921 - val_loss: 0.5099 - val_accuracy: 0.8002
# Epoch 62/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5326 - accuracy: 0.7905 - val_loss: 0.5067 - val_accuracy: 0.8032
# Epoch 63/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5297 - accuracy: 0.7921 - val_loss: 0.5084 - val_accuracy: 0.8004
# Epoch 64/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5202 - accuracy: 0.7938 - val_loss: 0.5076 - val_accuracy: 0.8017
# Epoch 65/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5121 - accuracy: 0.8048 - val_loss: 0.5055 - val_accuracy: 0.8006
# Epoch 66/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5202 - accuracy: 0.7928 - val_loss: 0.5053 - val_accuracy: 0.8023
# Epoch 67/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5215 - accuracy: 0.7938 - val_loss: 0.5029 - val_accuracy: 0.8036
# Epoch 68/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5163 - accuracy: 0.8027 - val_loss: 0.5020 - val_accuracy: 0.8045
# Epoch 69/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5143 - accuracy: 0.8004 - val_loss: 0.5020 - val_accuracy: 0.8049
# Epoch 70/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5138 - accuracy: 0.7949 - val_loss: 0.5001 - val_accuracy: 0.8067
# Epoch 71/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5147 - accuracy: 0.7997 - val_loss: 0.5019 - val_accuracy: 0.8041
# Epoch 72/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5191 - accuracy: 0.7963 - val_loss: 0.4992 - val_accuracy: 0.8067
# Epoch 73/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4999 - accuracy: 0.8012 - val_loss: 0.4985 - val_accuracy: 0.8067
# Epoch 74/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5093 - accuracy: 0.8069 - val_loss: 0.4973 - val_accuracy: 0.8075
# Epoch 75/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5050 - accuracy: 0.7958 - val_loss: 0.4989 - val_accuracy: 0.8056
# Epoch 76/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5032 - accuracy: 0.8024 - val_loss: 0.4966 - val_accuracy: 0.8067
# Epoch 77/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4959 - accuracy: 0.8068 - val_loss: 0.4955 - val_accuracy: 0.8075
# Epoch 78/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5048 - accuracy: 0.8040 - val_loss: 0.4946 - val_accuracy: 0.8088
# Epoch 79/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4990 - accuracy: 0.8052 - val_loss: 0.4961 - val_accuracy: 0.8073
# Epoch 80/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4925 - accuracy: 0.8108 - val_loss: 0.4918 - val_accuracy: 0.8104
# Epoch 81/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4906 - accuracy: 0.8101 - val_loss: 0.4939 - val_accuracy: 0.8082
# Epoch 82/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4905 - accuracy: 0.8078 - val_loss: 0.4898 - val_accuracy: 0.8104
# Epoch 83/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5035 - accuracy: 0.8026 - val_loss: 0.4904 - val_accuracy: 0.8084
# Epoch 84/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4759 - accuracy: 0.8171 - val_loss: 0.4886 - val_accuracy: 0.8106
# Epoch 85/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4850 - accuracy: 0.8101 - val_loss: 0.4880 - val_accuracy: 0.8125
# Epoch 86/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4890 - accuracy: 0.8127 - val_loss: 0.4908 - val_accuracy: 0.8073
# Epoch 87/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.4857 - accuracy: 0.8067 - val_loss: 0.4904 - val_accuracy: 0.8089
# Epoch 88/100
# 25/25 [==============================] - 3s 129ms/step - loss: 0.4888 - accuracy: 0.8091 - val_loss: 0.4869 - val_accuracy: 0.8125
# Epoch 89/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.4889 - accuracy: 0.8088 - val_loss: 0.4890 - val_accuracy: 0.8117
# Epoch 90/100
# 25/25 [==============================] - 3s 132ms/step - loss: 0.4869 - accuracy: 0.8150 - val_loss: 0.4858 - val_accuracy: 0.8138
# Epoch 91/100
# 25/25 [==============================] - 3s 129ms/step - loss: 0.4777 - accuracy: 0.8184 - val_loss: 0.4859 - val_accuracy: 0.8127
# Epoch 92/100
# 25/25 [==============================] - 3s 130ms/step - loss: 0.4855 - accuracy: 0.8122 - val_loss: 0.4832 - val_accuracy: 0.8123
# Epoch 93/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.4792 - accuracy: 0.8144 - val_loss: 0.4832 - val_accuracy: 0.8121
# Epoch 94/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.4691 - accuracy: 0.8207 - val_loss: 0.4837 - val_accuracy: 0.8121
# Epoch 95/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.4674 - accuracy: 0.8213 - val_loss: 0.4834 - val_accuracy: 0.8123
# Epoch 96/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4759 - accuracy: 0.8159 - val_loss: 0.4815 - val_accuracy: 0.8138
# Epoch 97/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4549 - accuracy: 0.8223 - val_loss: 0.4833 - val_accuracy: 0.8121
# Epoch 98/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4815 - accuracy: 0.8138 - val_loss: 0.4817 - val_accuracy: 0.8134
# Epoch 99/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.4763 - accuracy: 0.8157 - val_loss: 0.4839 - val_accuracy: 0.8115
# Epoch 100/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4716 - accuracy: 0.8135 - val_loss: 0.4810 - val_accuracy: 0.8139

# %%
(end - start)/ 60
# Out:
# 5.790239892133331

# %%
acc_train = hist.history['accuracy']
acc_test = hist.history['val_accuracy']
loss_train = hist.history['loss']
loss_test = hist.history['val_loss']

plt.axes().set_facecolor('gray')
plt.grid('True')


plt.plot(loss_train, color='green', label='Train loss')
plt.plot(loss_test, color='yellow', label='Test loss')
plt.plot(acc_train, color='blue', label='Train acc')
plt.plot(acc_test, color='red', label='Test acc')


plt.show()

# %%
acc_train = hist.history['accuracy']
acc_test = hist.history['val_accuracy']

plt.axes().set_facecolor('gray')
plt.grid('True')


plt.plot(acc_train, color='blue', label='Train acc');
plt.plot(acc_test, color='red', label='Test acc');

# %%
loss_train = hist.history['loss']
loss_test = hist.history['val_loss']

plt.axes().set_facecolor('gray')
plt.grid('True')


plt.plot(loss_train, color='blue', label='Train loss');
plt.plot(loss_test, color='red', label='Test loss');

# %%
model_cnn.evaluate(x=x_test, y=y_test)
model_cnn.evaluate(x=x_train, y=y_train)
# Out:
# 169/169 [==============================] - 12s 36ms/step - loss: 0.4810 - accuracy: 0.8139
# 394/394 [==============================] - 7s 18ms/step - loss: 0.4135 - accuracy: 0.8420
# [0.4135127365589142, 0.8419588208198547]

# %%
y_pred_train = model_cnn.predict(x_train)
y_pred_test = model_cnn.predict(x_test)


index_train = random.randint(0, 12579)
print(f'y_train: {y_train[index_train]} y_pred_train:{y_pred_train[index_train]}')

index_test = random.randint(0, 5391)
print(f'y_test: {y_test[index_test]} y_pred_test:{y_pred_test[index_test]}')
# Out:
# y_train: 2 y_pred_train:[0.0062627  0.29592273 0.6978146 ]
# y_test: 0 y_pred_test:[0.9605287  0.03283134 0.00663996]

# %%
y_pred_train_smax = softmax(y_pred_train, axis=1)
y_pred_test_smax = softmax(y_pred_test, axis=1)

y_pred_train_smax = np.argmax(y_pred_train_smax, axis=1)
y_pred_test_smax = np.argmax(y_pred_test_smax, axis=1)


y_pred_test_smax.shape, y_pred_train_smax.shape
# Out:
# ((5391,), (12579,))

# %%
acc_train = accuracy_score(y_train, y_pred_train_smax)
acc_test = accuracy_score(y_test, y_pred_test_smax)

p = precision_score(y_test, y_pred_test_smax, average='micro')
r = recall_score(y_test, y_pred_test_smax, average='micro')


print(f'Acc Train: {acc_train} - Acc Test: {acc_test} - Percision: {p} - Recall: {r}')
# Out:
# Acc Train: 0.8419588202559822 - Acc Test: 0.8139491745501762 - Percision: 0.8139491745501762 - Recall: 0.8139491745501762

# %%
cm_train = confusion_matrix(y_true=y_train, y_pred=y_pred_train_smax)
disp_cm_train = ConfusionMatrixDisplay(cm_train)

cm_train = cm_train.astype('float') / cm_train.sum(axis=1)[:, np.newaxis]
disp_cm_train_perce = ConfusionMatrixDisplay(cm_train)


fig , (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.set_title('Values')
ax2.set_title('Percentage')
disp_cm_train.plot(ax=ax1);
disp_cm_train_perce.plot(ax=ax2);

# %%
cm_test = confusion_matrix(y_true=y_test, y_pred=y_pred_test_smax)
disp_cm_test = ConfusionMatrixDisplay(cm_test)

cm_test = cm_test.astype('float') / cm_test.sum(axis=1)[:, np.newaxis]
disp_cm_test_perce = ConfusionMatrixDisplay(cm_test)


fig , (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.set_title('Values')
ax2.set_title('Percentage')
disp_cm_test.plot(ax=ax1);
disp_cm_test_perce.plot(ax=ax2);

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import backend as K
import numpy as np

# Custom Symmetry Regularization Function
def symmetry_regularization(features, symmetry_score_mean):
    # Flip features horizontally
    flipped_features = tf.image.flip_left_right(features)
    
    # Compute L2 loss between features and flipped features as symmetry constraint
    symmetry_loss = tf.reduce_mean(tf.square(features - flipped_features))
    
    # Weight symmetry loss with class-specific mean symmetry score
    return symmetry_loss * (1 - symmetry_score_mean)

# Custom Loss Function with Symmetry Regularization on Features
def custom_loss(y_true, y_pred, features, class_indices):
    # Classification loss
    base_loss = keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    
    # Symmetry scores for each class
    symmetry_scores_mean = [flipped_class_0_scores_mean, flipped_class_1_scores_mean, flipped_class_2_scores_mean]
    symmetry_score_mean = tf.gather(symmetry_scores_mean, class_indices)
    
    # Symmetry regularization on features
    symmetry_penalty = symmetry_regularization(features, symmetry_score_mean)
    
    return base_loss + symmetry_penalty

# Define Input Layer
inputs = keras.Input(shape=(50, 50, 1))

# Data Augmentation
x = layers.RandomFlip("horizontal")(inputs)

# CNN Layers
x = layers.Conv2D(8, kernel_size=(3, 3))(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = layers.Conv2D(16, kernel_size=(3, 3))(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Conv2D(32, kernel_size=(3, 3))(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Conv2D(64, kernel_size=(3, 3))(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Conv2D(64, kernel_size=(3, 3))(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Store CNN Features for Symmetry Regularization
features = x

# Dense Layers
x = layers.Flatten()(features)
x = layers.Dense(units=64, activation='relu')(x)
x = layers.Dropout(0.5)(x)

# Output Layer
outputs = layers.Dense(units=3, activation='softmax')(x)

# Define the Model
model_cnn = keras.Model(inputs=inputs, outputs=outputs)

# Compile with Custom Loss
def model_loss(y_true, y_pred):
    # Get class indices for each sample
    class_indices = tf.cast(y_true, tf.int32)
    
    # Compute custom loss
    return custom_loss(y_true, y_pred, features, class_indices)

optimizer = keras.optimizers.Adam(learning_rate=0.00002)
model_cnn.compile(optimizer=optimizer, loss=model_loss, metrics=['accuracy'])

# Model Summary
model_cnn.summary()
