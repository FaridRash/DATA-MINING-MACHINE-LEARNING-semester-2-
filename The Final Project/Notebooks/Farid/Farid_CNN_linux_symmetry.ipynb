# %% [markdown]
# #Libraries

# %%
import time
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from imutils import paths
from tensorflow import keras
import matplotlib.pyplot as plt
from collections import Counter
from tensorflow.nn import softmax 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, precision_score, recall_score
import seaborn as sns
import cv2
from skimage.metrics import structural_similarity as ssim
# Out:
# 2024-11-05 17:36:11.530905: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-11-05 17:36:17.693796: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-11-05 17:36:17.694814: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2024-11-05 17:36:17.713301: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 17:36:17.713612: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: Quadro P2000 computeCapability: 6.1
# coreClock: 1.607GHz coreCount: 6 deviceMemorySize: 3.94GiB deviceMemoryBandwidth: 89.53GiB/s
# 2024-11-05 17:36:17.713703: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-11-05 17:36:17.765247: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-11-05 17:36:17.765348: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-11-05 17:36:17.792834: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-11-05 17:36:17.799648: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-11-05 17:36:17.852767: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-11-05 17:36:17.859674: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-11-05 17:36:17.953278: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-11-05 17:36:17.953482: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 17:36:17.953792: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 17:36:17.953890: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %%
# Reading FRI Images
imagePaths = list(paths.list_images(r"/home/gunner/Dataset/FR0"))

data = []
data_cropped = []
labels = []
label = 0
counter_0 = 0

for imagePath in imagePaths:
  image = tf.io.read_file(imagePath)
  image = tf.image.decode_image(image, channels=1)
  data.append(image)
  labels.append(label)
  counter_0 += 1
print(f'Loaded FR0... {counter_0} files has loaded.')
# Out:
# 2024-11-05 17:36:24.512740: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-05 17:36:24.514487: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-11-05 17:36:24.514796: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 17:36:24.514961: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: Quadro P2000 computeCapability: 6.1
# coreClock: 1.607GHz coreCount: 6 deviceMemorySize: 3.94GiB deviceMemoryBandwidth: 89.53GiB/s
# 2024-11-05 17:36:24.515010: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-11-05 17:36:24.515074: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-11-05 17:36:24.515098: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-11-05 17:36:24.515119: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-11-05 17:36:24.515138: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-11-05 17:36:24.515156: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-11-05 17:36:24.515175: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-11-05 17:36:24.515193: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-11-05 17:36:24.515293: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 17:36:24.515449: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 17:36:24.515563: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-11-05 17:36:24.516341: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-11-05 17:36:25.793103: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-11-05 17:36:25.793138: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2024-11-05 17:36:25.793145: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2024-11-05 17:36:25.794114: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 17:36:25.794491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 17:36:25.794656: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-05 17:36:25.794797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3571 MB memory) -> physical GPU (device: 0, name: Quadro P2000, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Loaded FR0... 6066 files has loaded.

# %%
# Reading FRI Images
imagePaths = list(paths.list_images(r"/home/gunner/Dataset/FRI"))


label = 1
counter_1 = 0

for imagePath in imagePaths:
  image = tf.io.read_file(imagePath)
  image = tf.image.decode_image(image, channels=1)
  data.append(image)
  labels.append(label)
  counter_1 += 1
print(f'Loaded FRI... {counter_1} files has loaded.')
# Out:
# Loaded FRI... 5008 files has loaded.

# %%
# Reading FRI Images
imagePaths = list(paths.list_images(r"/home/gunner/Dataset/FRII"))

label = 2
counter_2 = 0

for imagePath in imagePaths:
  image = tf.io.read_file(imagePath)
  image = tf.image.decode_image(image, channels=1)
  data.append(image)
  labels.append(label)
  counter_2 += 1
print(f'Loaded FRII... {counter_2} files has loaded.')
# Out:
# Loaded FRII... 2066 files has loaded.

# %% [markdown]
# #**Cropping**

# %%
data_cropped = []
for image in data:
  image = tf.image.crop_to_bounding_box(image, 120, 120, 60, 60)
  data_cropped.append(image)

# %% [markdown]
# #**EDA**

# %%
counter = Counter(labels)
sorted_counts = dict(sorted(counter.items()))
plt.bar(sorted_counts.keys(), sorted_counts.values(), color='skyblue')
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Each Class in the Dataset')
plt.xticks(range(3))
plt.show()

# %%
labels = np.array(labels,dtype='uint8')
data = np.array(data,dtype='uint8')
data_cropped = np.array(data_cropped,dtype='uint8')

# %%
class_0 = data[labels == 0]
image = np.squeeze(class_0[1])
plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FR0")

class_1 = data[labels == 1]
image = np.squeeze(class_1[1])
plt.subplot(1, 3, 2)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRI")

class_2 = data[labels == 2]
image = np.squeeze(class_2[1])
plt.subplot(1, 3, 3)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRII")


plt.show()

# %%
class_0 = data_cropped[labels == 0]
image = np.squeeze(class_0[1])
plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FR0")

class_1 = data_cropped[labels == 1]
image = np.squeeze(class_1[1])
plt.subplot(1, 3, 2)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRI")

class_2 = data_cropped[labels == 2]
image = np.squeeze(class_2[1])
plt.subplot(1, 3, 3)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRII")


plt.show()

# %% [markdown]
# #**Filterring**

# %%
data_cropped.shape, labels.shape
# Out:
# ((13140, 60, 60, 1), (13140,))

# %%
mask = np.array([np.max(image) >= 5 for image in data_cropped])
filtered_data = data_cropped[mask]
filtered_labels = labels[mask]

# %%
mask_useless = np.array([np.max(image) < 5 for image in data_cropped])
useless_data = data_cropped[mask_useless]
useless_labels = labels[mask_useless]

# %%
class_0_useless = useless_data[useless_labels == 0]
class_1_useless = useless_data[useless_labels == 1]
class_2_useless = useless_data[useless_labels == 2]

# %%
np.max(class_0_useless), np.max(class_1_useless), np.max(class_2_useless)
# Out:
# (2, 0, 2)

# %%
class_0_useless.shape, class_1_useless.shape, class_2_useless.shape
# Out:
# ((94, 60, 60, 1), (40, 60, 60, 1), (36, 60, 60, 1))

# %%
temp = 0
for i in class_0_useless:
  if np.max(i) >temp:
    temp = np.max(i)
    image = np.squeeze(i)
plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FR0")

temp = 0
for i in class_1_useless:
  if np.max(i) >temp:
    temp = np.max(i)
    image = np.squeeze(i)
plt.subplot(1, 3, 2)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRI")

temp = 0
for i in class_2_useless:
  if np.max(i) >temp:
    temp = np.max(i)
    image = np.squeeze(i)
plt.subplot(1, 3, 3)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRII")


plt.show()

# %%
counter = Counter(filtered_labels)
sorted_counts = dict(sorted(counter.items()))
plt.bar(sorted_counts.keys(), sorted_counts.values(), color='skyblue')
plt.grid(True)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Each Class in the Dataset')
plt.xticks(range(3))
plt.show()

# %%
class_0_image = filtered_data[filtered_labels == 0]
class_1_image = filtered_data[filtered_labels == 1]
class_2_image = filtered_data[filtered_labels == 2]
class_0_image.shape, class_1_image.shape, class_2_image.shape
# Out:
# ((5972, 60, 60, 1), (4968, 60, 60, 1), (2030, 60, 60, 1))

# %% [markdown]
# #**Augmentation**

# %%
datagen = ImageDataGenerator(rotation_range=30,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             shear_range=0.2,
                             horizontal_flip=True,
                             fill_mode='nearest')
class_2_data = filtered_data[filtered_labels == 2]
class_1_data = filtered_data[filtered_labels == 1]


augmented_class_2_data = []
augmented_class_2_labels = []

for i in range(4000):
    image = class_2_data[np.random.randint(0, len(class_2_data))]
    augmented_image = datagen.random_transform(image)
    augmented_class_2_data.append(augmented_image)
    augmented_class_2_labels.append(2)



augmented_class_1_data = []
augmented_class_1_labels = []

for i in range(1000):
    image = class_1_data[np.random.randint(0, len(class_1_data))]
    augmented_image = datagen.random_transform(image)
    augmented_class_1_data.append(augmented_image)
    augmented_class_1_labels.append(1)

# %%
augmented_class_2_data = np.array(augmented_class_2_data)
augmented_class_2_labels = np.array(augmented_class_2_labels)

augmented_class_1_data = np.array(augmented_class_1_data)
augmented_class_1_labels = np.array(augmented_class_1_labels)

final_data = np.concatenate((filtered_data, augmented_class_2_data, augmented_class_1_data), axis=0)
final_labels = np.concatenate((filtered_labels, augmented_class_2_labels, augmented_class_1_labels), axis=0)

# %%
print("Final data shape:", final_data.shape)
print("Final labels shape:", final_labels.shape)
# Out:
# Final data shape: (17970, 60, 60, 1)
# Final labels shape: (17970,)

# %%
counter = Counter(final_labels)
sorted_counts = dict(sorted(counter.items()))
plt.bar(sorted_counts.keys(), sorted_counts.values(), color='skyblue')
plt.grid(True)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Each Class in the Dataset')
plt.xticks(range(3))
plt.show()

# %%
class_0_flatten = []
class_1_flatten = []
class_2_flatten = []


for image in final_data[final_labels == 0]:
    class_0_flatten.append(image.flatten())

for image in final_data[final_labels == 1]:
    class_1_flatten.append(image.flatten())

for image in final_data[final_labels == 2]:
    class_2_flatten.append(image.flatten())


class_0_flatten = np.array(class_0_flatten, dtype='uint8')
class_1_flatten = np.array(class_1_flatten, dtype='uint8')
class_2_flatten = np.array(class_2_flatten, dtype='uint8')

class_0_flatten.shape, class_1_flatten.shape, class_2_flatten.shape, final_data.shape, final_labels.shape
# Out:
# ((5972, 3600), (5968, 3600), (6030, 3600), (17970, 60, 60, 1), (17970,))

# %% [markdown]
# #**Flatten images**

# %%
for i in range(5):
    plt.plot(class_0_flatten[i], color='red')

plt.show();

# %%
for i in range(5):
    plt.plot(class_1_flatten[i], color='red')

plt.show();

# %%
for i in range(5):
    plt.plot(class_2_flatten[i], color='red')
    
plt.show();

# %% [markdown]
# #**Pixels mean**

# %%
class_0_mean = np.mean(class_0_flatten, axis=0)

plt.plot(class_0_mean)
plt.show()

# %%
class_1_mean = np.mean(class_1_flatten, axis=0)

plt.plot(class_1_mean)
plt.show()

# %%
class_2_mean = np.mean(class_2_flatten, axis=0)

plt.plot(class_2_mean)
plt.show()

# %% [markdown]
# #**Pixels Correlation**

# %%
correlation_matrix = np.corrcoef(class_0_flatten, rowvar=False)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Pixel Correlation Matrix Across All Classes")
plt.xlabel("Pixel Index")
plt.ylabel("Pixel Index")
plt.show()

# %%
correlation_matrix = np.corrcoef(class_1_flatten, rowvar=False)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Pixel Correlation Matrix Across All Classes")
plt.xlabel("Pixel Index")
plt.ylabel("Pixel Index")
plt.show()

# %%
correlation_matrix = np.corrcoef(class_2_flatten, rowvar=False)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Pixel Correlation Matrix Across All Classes")
plt.xlabel("Pixel Index")
plt.ylabel("Pixel Index")
plt.show()

# %% [markdown]
# #**Sobel**

# %%
class_0_image = final_data[final_labels == 0]
class_1_image = final_data[final_labels == 1]
class_2_image = final_data[final_labels == 2]

# %%
class_0_image.shape, class_1_image.shape, class_2_image.shape
# Out:
# ((5972, 60, 60, 1), (5968, 60, 60, 1), (6030, 60, 60, 1))

# %%
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)
edge_image = np.sqrt(sobel_x**2 + sobel_y**2)

plt.figure(figsize=(12, 6))
for i in range(3):
    image = class_0_image[i]
    sobel_x = cv2.Sobel(class_0_image[i], cv2.CV_64F, 1, 0, ksize=5)
    sobel_y = cv2.Sobel(class_0_image[i], cv2.CV_64F, 0, 1, ksize=5)   
    edge_image = np.sqrt(sobel_x**2 + sobel_y**2)
    plt.subplot(2, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"Original FR0 {i+1}")
    plt.axis('off')

    plt.subplot(2, 5, i+6)
    plt.imshow(edge_image, cmap='gray')
    plt.title(f"Sobel Edges FR0 {i+1}")
    plt.axis('off')

# %%
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)
edge_image = np.sqrt(sobel_x**2 + sobel_y**2)

plt.figure(figsize=(12, 6))
for i in range(3):
    image = class_1_image[i]
    sobel_x = cv2.Sobel(class_1_image[i], cv2.CV_64F, 1, 0, ksize=5)
    sobel_y = cv2.Sobel(class_1_image[i], cv2.CV_64F, 0, 1, ksize=5)   
    edge_image = np.sqrt(sobel_x**2 + sobel_y**2)
    plt.subplot(2, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"Original FRI {i+1}")
    plt.axis('off')

    plt.subplot(2, 5, i+6)
    plt.imshow(edge_image, cmap='gray')
    plt.title(f"Sobel Edges FRI {i+1}")
    plt.axis('off')

# %%
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)
edge_image = np.sqrt(sobel_x**2 + sobel_y**2)

plt.figure(figsize=(12, 6))
for i in range(1, 4):
    image = class_2_image[i]
    sobel_x = cv2.Sobel(class_2_image[i], cv2.CV_64F, 1, 0, ksize=5)
    sobel_y = cv2.Sobel(class_2_image[i], cv2.CV_64F, 0, 1, ksize=5)   
    edge_image = np.sqrt(sobel_x**2 + sobel_y**2)
    plt.subplot(2, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"Original FRII {i+1}")
    plt.axis('off')

    plt.subplot(2, 5, i+6)
    plt.imshow(edge_image, cmap='gray')
    plt.title(f"Sobel Edges FRII {i+1}")
    plt.axis('off')

# %% [markdown]
# #**Symmetry**

# %%
plt.figure(figsize=(12, 6))
for i in range(3):
    image = class_0_image[i]
    image = cv2.resize(image, (50, 50))  

    flipped_image = cv2.flip(image, 1)

    symmetry_score, _ = ssim(image, flipped_image, full=True)


    # Original Image
    plt.subplot(3, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"FR0 {i+1}")
    plt.axis('off')

    # Flipped Image
    flipped_image = cv2.flip(image, 1)
    plt.subplot(3, 5, i+6)
    plt.imshow(flipped_image, cmap='gray')
    plt.title(f"Flipped FR0 {i+1}")
    plt.axis('off')

    # Symmetry Score
    plt.subplot(3, 5, i+11)
    plt.text(0.5, 0.5, f"SSIM: {symmetry_score:.2f}", ha='center', va='center', fontsize=12)
    plt.axis('off')

# %%
plt.figure(figsize=(12, 6))
for i in range(3):
    image = class_1_image[i]
    image = cv2.resize(image, (50, 50))  

    flipped_image = cv2.flip(image, 1)

    symmetry_score, _ = ssim(image, flipped_image, full=True)


    # Original Image
    plt.subplot(3, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"FRI {i+1}")
    plt.axis('off')

    # Flipped Image
    flipped_image = cv2.flip(image, 1)
    plt.subplot(3, 5, i+6)
    plt.imshow(flipped_image, cmap='gray')
    plt.title(f"Flipped FRI {i+1}")
    plt.axis('off')

    # Symmetry Score
    plt.subplot(3, 5, i+11)
    plt.text(0.5, 0.5, f"SSIM: {symmetry_score:.2f}", ha='center', va='center', fontsize=12)
    plt.axis('off')

# %%
plt.figure(figsize=(12, 6))
for i in range(1, 4):
    image = class_2_image[i]
    image = cv2.resize(image, (50, 50))  

    flipped_image = cv2.flip(image, 1)

    symmetry_score, _ = ssim(image, flipped_image, full=True)


    # Original Image
    plt.subplot(3, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"FRII {i+1}")
    plt.axis('off')

    # Flipped Image
    flipped_image = cv2.flip(image, 1)
    plt.subplot(3, 5, i+6)
    plt.imshow(flipped_image, cmap='gray')
    plt.title(f"Flipped FRII {i+1}")
    plt.axis('off')

    # Symmetry Score
    plt.subplot(3, 5, i+11)
    plt.text(0.5, 0.5, f"SSIM: {symmetry_score:.2f}", ha='center', va='center', fontsize=12)
    plt.axis('off')

# %%
flipped_class_0_scores = []

for i in class_0_image:
    image = cv2.resize(i, (50, 50))  
    flipped_image = cv2.flip(image, 1)
    symmetry_score, _ = ssim(image, flipped_image, full=True)
    flipped_class_0_scores.append(symmetry_score)

flipped_class_0_scores = np.array(flipped_class_0_scores)
flipped_class_0_scores_mean = np.mean(flipped_class_0_scores)
flipped_class_0_scores.shape
# Out:
# (5972,)

# %%
flipped_class_1_scores = []

for i in class_1_image:
    image = cv2.resize(i, (50, 50))  
    flipped_image = cv2.flip(image, 1)
    symmetry_score, _ = ssim(image, flipped_image, full=True)
    flipped_class_1_scores.append(symmetry_score)

flipped_class_1_scores = np.array(flipped_class_1_scores)
flipped_class_1_scores_mean = np.mean(flipped_class_1_scores)
flipped_class_1_scores.shape
# Out:
# (5968,)

# %%
flipped_class_2_scores = []

for i in class_2_image:
    image = cv2.resize(i, (50, 50))  
    flipped_image = cv2.flip(image, 1)
    symmetry_score, _ = ssim(image, flipped_image, full=True)
    flipped_class_2_scores.append(symmetry_score)

flipped_class_2_scores = np.array(flipped_class_2_scores)
flipped_class_2_scores_mean = np.mean(flipped_class_2_scores)
flipped_class_2_scores.shape
# Out:
# (6030,)

# %%
print(f'FR0 numbers: {flipped_class_0_scores.shape} , FRI Numbers: {flipped_class_1_scores.shape}, FRII Numbers: {flipped_class_2_scores.shape}')
print(f'FR0 Symmetry Score: {flipped_class_0_scores_mean:0.2f} , FRI Symmetry Score: {flipped_class_1_scores_mean:0.2f}, FRII Symmetry Score: {flipped_class_2_scores_mean:0.2f}')


flipped_labels = ['FR0', 'FRI', 'FRII']
flipped_values = [flipped_class_0_scores_mean, flipped_class_1_scores_mean, flipped_class_2_scores_mean]
plt.bar(flipped_labels, flipped_values)
plt.show()
# Out:
# FR0 numbers: (5972,) , FRI Numbers: (5968,), FRII Numbers: (6030,)
# FR0 Symmetry Score: 0.95 , FRI Symmetry Score: 0.82, FRII Symmetry Score: 0.69

# %% [markdown]
# #**Preprocessing**

# %%
np.min(final_data[0]), np.max(final_data[0])
# Out:
# (0, 251)

# %%
data_normalized = final_data / 255

# %%
print(f'Min of original = {np.min(final_data[0])}')
print(f'Max of original = {np.max(final_data[0])}')
print(f'Min of original = {np.min(data_normalized[0])}')
print(f'Max of original = {np.max(data_normalized[0])}')
# Out:
# Min of original = 0
# Max of original = 251
# Min of original = 0.0
# Max of original = 0.984313725490196

# %%
cropped_flat = final_data.flatten()
normalized_flat = data_normalized.flatten()

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.boxplot(cropped_flat)
plt.title("Original Pixel Values (0-255)")
plt.ylabel("Pixel Intensity")

plt.subplot(1, 2, 2)
plt.boxplot(normalized_flat)
plt.title("Normalized Pixel Values (0-1)")
plt.ylabel("Pixel Intensity")

plt.tight_layout()
plt.show()

# %% [markdown]
# #***An explanation about the data frames***
#
# #**data_cropped -->> filtered_data -->> final_data -->> data_normalized**
#
# #**labels -->> filtered_labels -->> final_labels**

# %% [markdown]
# #**Splitting**

# %%
x = data_normalized
y = final_labels
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((12579, 60, 60, 1), (12579,), (5391, 60, 60, 1), (5391,))

# %% [markdown]
# #**CNN**

# %%
model_cnn = keras.Sequential()

#Seed
tf.random.set_seed(42)

#CNN
model_cnn.add(keras.layers.Conv2D(8, kernel_size=(3,3), input_shape=(60, 60, 1)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))

model_cnn.add(keras.layers.Conv2D(16, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))
model_cnn.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model_cnn.add(keras.layers.Conv2D(32, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))
model_cnn.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model_cnn.add(keras.layers.Conv2D(64, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))
model_cnn.add(keras.layers.MaxPool2D(pool_size=(2, 2)))

model_cnn.add(keras.layers.Conv2D(64, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))
model_cnn.add(keras.layers.MaxPool2D(pool_size=(2, 2)))


#Dense
model_cnn.add(keras.layers.Flatten())
model_cnn.add(keras.layers.Dense(units=64, activation='relu'))
model_cnn.add(keras.layers.Dropout(0.5))



#Output
model_cnn.add(keras.layers.Dense(units=3, activation=keras.activations.softmax))


#Model Compiling
optimizer = keras.optimizers.Adam(learning_rate=0.00002)
loss = keras.losses.SparseCategoricalCrossentropy()
metric = [keras.metrics.CategoricalAccuracy()]

model_cnn.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])


#Builing and Summury
model_cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 58, 58, 8)         80
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 58, 58, 8)         32
# _________________________________________________________________
# activation_5 (Activation)    (None, 58, 58, 8)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 16)        1168
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 56, 56, 16)        64
# _________________________________________________________________
# activation_6 (Activation)    (None, 56, 56, 16)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 26, 26, 32)        4640
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 26, 26, 32)        128
# _________________________________________________________________
# activation_7 (Activation)    (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 11, 11, 64)        256
# _________________________________________________________________
# activation_8 (Activation)    (None, 11, 11, 64)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 3, 3, 64)          256
# _________________________________________________________________
# activation_9 (Activation)    (None, 3, 3, 64)          0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 66,403
# Trainable params: 66,035
# Non-trainable params: 368
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

# %%
start = time.perf_counter()
hist = model_cnn.fit(x_train, y_train, batch_size=512, epochs=100, validation_data=(x_test, y_test), callbacks=[early_stopping])
end = time.perf_counter()
# Out:
# Epoch 1/100
# 25/25 [==============================] - 28s 721ms/step - loss: 1.6199 - accuracy: 0.3572 - val_loss: 1.1030 - val_accuracy: 0.3296
# Epoch 2/100
# 25/25 [==============================] - 3s 127ms/step - loss: 1.2678 - accuracy: 0.4246 - val_loss: 1.1089 - val_accuracy: 0.3296
# Epoch 3/100
# 25/25 [==============================] - 3s 127ms/step - loss: 1.1511 - accuracy: 0.4692 - val_loss: 1.1131 - val_accuracy: 0.3255
# Epoch 4/100
# 25/25 [==============================] - 3s 127ms/step - loss: 1.0672 - accuracy: 0.5024 - val_loss: 1.1159 - val_accuracy: 0.3348
# Epoch 5/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.9933 - accuracy: 0.5383 - val_loss: 1.1179 - val_accuracy: 0.3350
# Epoch 6/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.9349 - accuracy: 0.5672 - val_loss: 1.1193 - val_accuracy: 0.3350
# Epoch 7/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.8977 - accuracy: 0.5832 - val_loss: 1.1218 - val_accuracy: 0.3350
# Epoch 8/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.8592 - accuracy: 0.6025 - val_loss: 1.1236 - val_accuracy: 0.3350
# Epoch 9/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.8296 - accuracy: 0.6199 - val_loss: 1.1207 - val_accuracy: 0.3350
# Epoch 10/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.8149 - accuracy: 0.6371 - val_loss: 1.1083 - val_accuracy: 0.3352
# Epoch 11/100
# 25/25 [==============================] - 3s 128ms/step - loss: 0.7895 - accuracy: 0.6392 - val_loss: 1.0920 - val_accuracy: 0.3357
# Epoch 12/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.7515 - accuracy: 0.6681 - val_loss: 1.0668 - val_accuracy: 0.3426
# Epoch 13/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.7486 - accuracy: 0.6669 - val_loss: 1.0294 - val_accuracy: 0.3665
# Epoch 14/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.7447 - accuracy: 0.6707 - val_loss: 0.9838 - val_accuracy: 0.5231
# Epoch 15/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.7139 - accuracy: 0.6879 - val_loss: 0.9347 - val_accuracy: 0.6160
# Epoch 16/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.7144 - accuracy: 0.6919 - val_loss: 0.8832 - val_accuracy: 0.6630
# Epoch 17/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6977 - accuracy: 0.6960 - val_loss: 0.8394 - val_accuracy: 0.6997
# Epoch 18/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.7021 - accuracy: 0.6991 - val_loss: 0.7974 - val_accuracy: 0.7203
# Epoch 19/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6859 - accuracy: 0.7085 - val_loss: 0.7588 - val_accuracy: 0.7340
# Epoch 20/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6717 - accuracy: 0.7116 - val_loss: 0.7190 - val_accuracy: 0.7436
# Epoch 21/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6710 - accuracy: 0.7143 - val_loss: 0.6878 - val_accuracy: 0.7500
# Epoch 22/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6628 - accuracy: 0.7208 - val_loss: 0.6591 - val_accuracy: 0.7577
# Epoch 23/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6580 - accuracy: 0.7214 - val_loss: 0.6387 - val_accuracy: 0.7600
# Epoch 24/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6528 - accuracy: 0.7248 - val_loss: 0.6172 - val_accuracy: 0.7637
# Epoch 25/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6400 - accuracy: 0.7338 - val_loss: 0.6020 - val_accuracy: 0.7674
# Epoch 26/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6365 - accuracy: 0.7351 - val_loss: 0.5874 - val_accuracy: 0.7720
# Epoch 27/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6435 - accuracy: 0.7290 - val_loss: 0.5771 - val_accuracy: 0.7733
# Epoch 28/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6290 - accuracy: 0.7420 - val_loss: 0.5681 - val_accuracy: 0.7765
# Epoch 29/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6344 - accuracy: 0.7350 - val_loss: 0.5613 - val_accuracy: 0.7744
# Epoch 30/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6296 - accuracy: 0.7481 - val_loss: 0.5558 - val_accuracy: 0.7770
# Epoch 31/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6239 - accuracy: 0.7373 - val_loss: 0.5517 - val_accuracy: 0.7769
# Epoch 32/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6073 - accuracy: 0.7539 - val_loss: 0.5488 - val_accuracy: 0.7759
# Epoch 33/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6293 - accuracy: 0.7453 - val_loss: 0.5464 - val_accuracy: 0.7754
# Epoch 34/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6151 - accuracy: 0.7512 - val_loss: 0.5427 - val_accuracy: 0.7769
# Epoch 35/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.6124 - accuracy: 0.7456 - val_loss: 0.5402 - val_accuracy: 0.7767
# Epoch 36/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5994 - accuracy: 0.7525 - val_loss: 0.5379 - val_accuracy: 0.7804
# Epoch 37/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5964 - accuracy: 0.7592 - val_loss: 0.5367 - val_accuracy: 0.7800
# Epoch 38/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5927 - accuracy: 0.7543 - val_loss: 0.5345 - val_accuracy: 0.7806
# Epoch 39/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5958 - accuracy: 0.7539 - val_loss: 0.5332 - val_accuracy: 0.7811
# Epoch 40/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5935 - accuracy: 0.7567 - val_loss: 0.5311 - val_accuracy: 0.7830
# Epoch 41/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5778 - accuracy: 0.7663 - val_loss: 0.5287 - val_accuracy: 0.7850
# Epoch 42/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5826 - accuracy: 0.7673 - val_loss: 0.5273 - val_accuracy: 0.7832
# Epoch 43/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5748 - accuracy: 0.7755 - val_loss: 0.5267 - val_accuracy: 0.7822
# Epoch 44/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5657 - accuracy: 0.7659 - val_loss: 0.5244 - val_accuracy: 0.7858
# Epoch 45/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5727 - accuracy: 0.7650 - val_loss: 0.5233 - val_accuracy: 0.7859
# Epoch 46/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5743 - accuracy: 0.7663 - val_loss: 0.5229 - val_accuracy: 0.7863
# Epoch 47/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5650 - accuracy: 0.7767 - val_loss: 0.5202 - val_accuracy: 0.7869
# Epoch 48/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5599 - accuracy: 0.7777 - val_loss: 0.5189 - val_accuracy: 0.7880
# Epoch 49/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5665 - accuracy: 0.7717 - val_loss: 0.5198 - val_accuracy: 0.7884
# Epoch 50/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5618 - accuracy: 0.7806 - val_loss: 0.5170 - val_accuracy: 0.7887
# Epoch 51/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5490 - accuracy: 0.7874 - val_loss: 0.5146 - val_accuracy: 0.7895
# Epoch 52/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5602 - accuracy: 0.7770 - val_loss: 0.5131 - val_accuracy: 0.7913
# Epoch 53/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5490 - accuracy: 0.7811 - val_loss: 0.5117 - val_accuracy: 0.7926
# Epoch 54/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5512 - accuracy: 0.7831 - val_loss: 0.5109 - val_accuracy: 0.7930
# Epoch 55/100
# 25/25 [==============================] - 4s 154ms/step - loss: 0.5464 - accuracy: 0.7813 - val_loss: 0.5094 - val_accuracy: 0.7934
# Epoch 56/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.5461 - accuracy: 0.7841 - val_loss: 0.5087 - val_accuracy: 0.7939
# Epoch 57/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5537 - accuracy: 0.7858 - val_loss: 0.5072 - val_accuracy: 0.7971
# Epoch 58/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5517 - accuracy: 0.7834 - val_loss: 0.5070 - val_accuracy: 0.7958
# Epoch 59/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5408 - accuracy: 0.7874 - val_loss: 0.5047 - val_accuracy: 0.7993
# Epoch 60/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5441 - accuracy: 0.7824 - val_loss: 0.5047 - val_accuracy: 0.7978
# Epoch 61/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5330 - accuracy: 0.7962 - val_loss: 0.5030 - val_accuracy: 0.8023
# Epoch 62/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5258 - accuracy: 0.7920 - val_loss: 0.5010 - val_accuracy: 0.8000
# Epoch 63/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5356 - accuracy: 0.7894 - val_loss: 0.5007 - val_accuracy: 0.8010
# Epoch 64/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5367 - accuracy: 0.7947 - val_loss: 0.5002 - val_accuracy: 0.8015
# Epoch 65/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5344 - accuracy: 0.7949 - val_loss: 0.4982 - val_accuracy: 0.8012
# Epoch 66/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5379 - accuracy: 0.7869 - val_loss: 0.4986 - val_accuracy: 0.8015
# Epoch 67/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5234 - accuracy: 0.7946 - val_loss: 0.4974 - val_accuracy: 0.8019
# Epoch 68/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5169 - accuracy: 0.7935 - val_loss: 0.4952 - val_accuracy: 0.8075
# Epoch 69/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5050 - accuracy: 0.7966 - val_loss: 0.4946 - val_accuracy: 0.8050
# Epoch 70/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5169 - accuracy: 0.7959 - val_loss: 0.4939 - val_accuracy: 0.8049
# Epoch 71/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5141 - accuracy: 0.7989 - val_loss: 0.4928 - val_accuracy: 0.8049
# Epoch 72/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5242 - accuracy: 0.7927 - val_loss: 0.4921 - val_accuracy: 0.8060
# Epoch 73/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5158 - accuracy: 0.8067 - val_loss: 0.4915 - val_accuracy: 0.8037
# Epoch 74/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5012 - accuracy: 0.8103 - val_loss: 0.4902 - val_accuracy: 0.8049
# Epoch 75/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5026 - accuracy: 0.8022 - val_loss: 0.4888 - val_accuracy: 0.8093
# Epoch 76/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5086 - accuracy: 0.8052 - val_loss: 0.4888 - val_accuracy: 0.8073
# Epoch 77/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4996 - accuracy: 0.8103 - val_loss: 0.4881 - val_accuracy: 0.8056
# Epoch 78/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5083 - accuracy: 0.7987 - val_loss: 0.4871 - val_accuracy: 0.8073
# Epoch 79/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5074 - accuracy: 0.8069 - val_loss: 0.4855 - val_accuracy: 0.8095
# Epoch 80/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5089 - accuracy: 0.8042 - val_loss: 0.4857 - val_accuracy: 0.8071
# Epoch 81/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4962 - accuracy: 0.8058 - val_loss: 0.4848 - val_accuracy: 0.8125
# Epoch 82/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.5068 - accuracy: 0.8031 - val_loss: 0.4851 - val_accuracy: 0.8041
# Epoch 83/100
# 25/25 [==============================] - 3s 126ms/step - loss: 0.4980 - accuracy: 0.8040 - val_loss: 0.4831 - val_accuracy: 0.8114
# Epoch 84/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4967 - accuracy: 0.8077 - val_loss: 0.4820 - val_accuracy: 0.8112
# Epoch 85/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4956 - accuracy: 0.8113 - val_loss: 0.4810 - val_accuracy: 0.8117
# Epoch 86/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4834 - accuracy: 0.8144 - val_loss: 0.4804 - val_accuracy: 0.8102
# Epoch 87/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4925 - accuracy: 0.8144 - val_loss: 0.4798 - val_accuracy: 0.8117
# Epoch 88/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4896 - accuracy: 0.8126 - val_loss: 0.4796 - val_accuracy: 0.8108
# Epoch 89/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4943 - accuracy: 0.8126 - val_loss: 0.4790 - val_accuracy: 0.8112
# Epoch 90/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4870 - accuracy: 0.8141 - val_loss: 0.4783 - val_accuracy: 0.8110
# Epoch 91/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4844 - accuracy: 0.8122 - val_loss: 0.4770 - val_accuracy: 0.8125
# Epoch 92/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4905 - accuracy: 0.8129 - val_loss: 0.4770 - val_accuracy: 0.8101
# Epoch 93/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4902 - accuracy: 0.8127 - val_loss: 0.4763 - val_accuracy: 0.8132
# Epoch 94/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4838 - accuracy: 0.8174 - val_loss: 0.4757 - val_accuracy: 0.8127
# Epoch 95/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4834 - accuracy: 0.8147 - val_loss: 0.4750 - val_accuracy: 0.8136
# Epoch 96/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4748 - accuracy: 0.8179 - val_loss: 0.4741 - val_accuracy: 0.8128
# Epoch 97/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4802 - accuracy: 0.8192 - val_loss: 0.4736 - val_accuracy: 0.8134
# Epoch 98/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4785 - accuracy: 0.8184 - val_loss: 0.4737 - val_accuracy: 0.8130
# Epoch 99/100
# 25/25 [==============================] - 3s 127ms/step - loss: 0.4741 - accuracy: 0.8202 - val_loss: 0.4725 - val_accuracy: 0.8130
# Epoch 100/100
# 25/25 [==============================] - 3s 126ms/step - loss: 0.4743 - accuracy: 0.8188 - val_loss: 0.4722 - val_accuracy: 0.8132

# %%
(end - start)/ 60
# Out:
# 5.722355904600001

# %%
acc_train = hist.history['accuracy']
acc_test = hist.history['val_accuracy']
loss_train = hist.history['loss']
loss_test = hist.history['val_loss']

plt.axes().set_facecolor('gray')
plt.grid('True')


plt.plot(loss_train, color='green', label='Train loss')
plt.plot(loss_test, color='yellow', label='Test loss')
plt.plot(acc_train, color='blue', label='Train acc')
plt.plot(acc_test, color='red', label='Test acc')


plt.show()

# %%
acc_train = hist.history['accuracy']
acc_test = hist.history['val_accuracy']

plt.axes().set_facecolor('gray')
plt.grid('True')


plt.plot(acc_train, color='blue', label='Train acc');
plt.plot(acc_test, color='red', label='Test acc');

# %%
loss_train = hist.history['loss']
loss_test = hist.history['val_loss']

plt.axes().set_facecolor('gray')
plt.grid('True')


plt.plot(loss_train, color='blue', label='Train loss');
plt.plot(loss_test, color='red', label='Test loss');

# %%
model_cnn.evaluate(x=x_test, y=y_test)
model_cnn.evaluate(x=x_train, y=y_train)
# Out:
# 169/169 [==============================] - 13s 39ms/step - loss: 0.4722 - accuracy: 0.8132
# 394/394 [==============================] - 7s 18ms/step - loss: 0.4182 - accuracy: 0.8412
# [0.41815996170043945, 0.8411638736724854]

# %%
y_pred_train = model_cnn.predict(x_train)
y_pred_test = model_cnn.predict(x_test)


index_train = random.randint(0, 12579)
print(f'y_train: {y_train[index_train]} y_pred_train:{y_pred_train[index_train]}')

index_test = random.randint(0, 5391)
print(f'y_test: {y_test[index_test]} y_pred_test:{y_pred_test[index_test]}')
# Out:
# y_train: 1 y_pred_train:[0.84068465 0.14459711 0.01471825]
# y_test: 0 y_pred_test:[0.941493   0.04692418 0.01158287]

# %%
y_pred_train_smax = softmax(y_pred_train, axis=1)
y_pred_test_smax = softmax(y_pred_test, axis=1)

y_pred_train_smax = np.argmax(y_pred_train_smax, axis=1)
y_pred_test_smax = np.argmax(y_pred_test_smax, axis=1)


y_pred_test_smax.shape, y_pred_train_smax.shape
# Out:
# ((5391,), (12579,))

# %%
acc_train = accuracy_score(y_train, y_pred_train_smax)
acc_test = accuracy_score(y_test, y_pred_test_smax)

p = precision_score(y_test, y_pred_test_smax, average='micro')
r = recall_score(y_test, y_pred_test_smax, average='micro')


print(f'Acc Train: {acc_train} - Acc Test: {acc_test} - Percision: {p} - Recall: {r}')
# Out:
# Acc Train: 0.8411638445027426 - Acc Test: 0.813207197180486 - Percision: 0.813207197180486 - Recall: 0.813207197180486

# %%
cm_train = confusion_matrix(y_true=y_train, y_pred=y_pred_train_smax)
disp_cm_train = ConfusionMatrixDisplay(cm_train)

cm_train = cm_train.astype('float') / cm_train.sum(axis=1)[:, np.newaxis]
disp_cm_train_perce = ConfusionMatrixDisplay(cm_train)


fig , (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.set_title('Values')
ax2.set_title('Percentage')
disp_cm_train.plot(ax=ax1);
disp_cm_train_perce.plot(ax=ax2);

# %%
cm_test = confusion_matrix(y_true=y_test, y_pred=y_pred_test_smax)
disp_cm_test = ConfusionMatrixDisplay(cm_test)

cm_test = cm_test.astype('float') / cm_test.sum(axis=1)[:, np.newaxis]
disp_cm_test_perce = ConfusionMatrixDisplay(cm_test)


fig , (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.set_title('Values')
ax2.set_title('Percentage')
disp_cm_test.plot(ax=ax1);
disp_cm_test_perce.plot(ax=ax2);
