# %% [markdown]
# <a href="https://colab.research.google.com/github/FaridRash/DATA-MINING-MACHINE-LEARNING-semester-2-/blob/main/The%20Final%20Project/Notebooks/Farid/Farid_EDA_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://FaridRash: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@github.com/FaridRash/DATA-MINING-MACHINE-LEARNING-semester-2-.git DataMining
# Out:
# fatal: destination path 'DataMining' already exists and is not an empty directory.

# %%
# !unzip '/content/DataMining/The Final Project/Data/Dataset.zip' -d '/content/DataMining/The Final Project/Data/'
# Out:
# Archive:  /content/DataMining/The Final Project/Data/Dataset.zip
# replace /content/DataMining/The Final Project/Data/FR0/J000001.57-092940.3.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
from imutils import paths
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.model_selection import train_test_split
import random
from sklearn.metrics import accuracy_score, precision_score, recall_score
from scipy.special import softmax
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import time

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# #**Fetching**

# %%
# Reading FRI Images
imagePaths = list(paths.list_images(r"/content/DataMining/The Final Project/Data/FR0"))

data = []
data_cropped = []
labels = []
label = 0
counter_0 = 0

for imagePath in imagePaths:
  image = tf.io.read_file(imagePath)
  image = tf.image.decode_image(image, channels=1)
  data.append(image)
  image = tf.image.crop_to_bounding_box(image, 125, 125, 50, 50)
  data_cropped.append(image)
  labels.append(label)
  counter_0 += 1
print(f'Loaded FR0... {counter_0} files has loaded.')
# Out:
# Loaded FR0... 6066 files has loaded.

# %%
# Reading FRI Images
imagePaths = list(paths.list_images(r"/content/DataMining/The Final Project/Data/FRI"))


label = 1
counter_1 = 0

for imagePath in imagePaths:
  image = tf.io.read_file(imagePath)
  image = tf.image.decode_image(image, channels=1)
  data.append(image)
  image = tf.image.crop_to_bounding_box(image, 125, 125, 50, 50)
  data_cropped.append(image)
  labels.append(label)
  counter_1 += 1
print(f'Loaded FRI... {counter_1} files has loaded.')
# Out:
# Loaded FRI... 5008 files has loaded.

# %%
# Reading FRI Images
imagePaths = list(paths.list_images(r"/content/DataMining/The Final Project/Data/FRII"))

label = 2
counter_2 = 0

for imagePath in imagePaths:
  image = tf.io.read_file(imagePath)
  image = tf.image.decode_image(image, channels=1)
  data.append(image)
  image = tf.image.crop_to_bounding_box(image, 125, 125, 50, 50)
  data_cropped.append(image)
  labels.append(label)
  counter_2 += 1
print(f'Loaded FRII... {counter_2} files has loaded.')
# Out:
# Loaded FRII... 2066 files has loaded.

# %% [markdown]
# #**EDA**

# %%
counter = Counter(labels)
sorted_counts = dict(sorted(counter.items()))
plt.bar(sorted_counts.keys(), sorted_counts.values(), color='skyblue')
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Each Class in the Dataset')
plt.xticks(range(3))
plt.show()

# %%
labels = np.array(labels,dtype='uint8')
data = np.array(data,dtype='uint8')
data_cropped = np.array(data_cropped,dtype='uint8')

# %%
image = np.squeeze(data[0])
plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FR0")

image = np.squeeze(data[6066])
plt.subplot(1, 3, 2)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRI")

image = np.squeeze(data[11075])
plt.subplot(1, 3, 3)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRII")


plt.show()

# %%
image = np.squeeze(data_cropped[0])
plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FR0")

image = np.squeeze(data_cropped[6066])
plt.subplot(1, 3, 2)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRI")

image = np.squeeze(data_cropped[11075])
plt.subplot(1, 3, 3)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRII")


plt.show()

# %% [markdown]
# #Filterring

# %%
type(data_cropped), type(labels), data_cropped.shape, labels.shape
# Out:
# (numpy.ndarray, numpy.ndarray, (13140, 50, 50, 1), (13140,))

# %%
mask = np.array([np.max(image) >= 100 for image in data_cropped])
filtered_data = data_cropped[mask]
filtered_labels = labels[mask]

# %%
counter = Counter(filtered_labels)
sorted_counts = dict(sorted(counter.items()))
plt.bar(sorted_counts.keys(), sorted_counts.values(), color='skyblue')
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Each Class in the Dataset')
plt.xticks(range(3))
plt.show()

# %%
data.shape, data_cropped.shape, filtered_data.shape, filtered_labels.shape
# Out:
# ((13140, 300, 300, 1), (13140, 50, 50, 1), (11858, 50, 50, 1), (11858,))

# %%
np.min(data_cropped[0]), np.max(data_cropped[0])
# Out:
# (0, 248)

# %% [markdown]
# #Augmentation

# %%
datagen = ImageDataGenerator(rotation_range=30,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             shear_range=0.2,
                             horizontal_flip=True,
                             fill_mode='nearest')
class_2_data = filtered_data[filtered_labels == 2]
class_1_data = filtered_data[filtered_labels == 1]


augmented_class_2_data = []
augmented_class_2_labels = []

for i in range(3000):
    image = class_2_data[np.random.randint(0, len(class_2_data))]
    augmented_image = datagen.random_transform(image)
    augmented_class_2_data.append(augmented_image)
    augmented_class_2_labels.append(2)



augmented_class_1_data = []
augmented_class_1_labels = []

for i in range(500):
    image = class_1_data[np.random.randint(0, len(class_1_data))]
    augmented_image = datagen.random_transform(image)
    augmented_class_1_data.append(augmented_image)
    augmented_class_1_labels.append(1)

# %%
augmented_class_2_data = np.array(augmented_class_2_data)
augmented_class_2_labels = np.array(augmented_class_2_labels)

augmented_class_1_data = np.array(augmented_class_1_data)
augmented_class_1_labels = np.array(augmented_class_1_labels)

final_data = np.concatenate((filtered_data, augmented_class_2_data, augmented_class_1_data), axis=0)
final_labels = np.concatenate((filtered_labels, augmented_class_2_labels, augmented_class_1_labels), axis=0)

# %%
print("Final data shape:", augmented_class_1_data.shape)
print("Final labels shape:", augmented_class_2_data.shape)
print("Final data shape:", final_data.shape)
print("Final labels shape:", final_labels.shape)
# Out:
# Final data shape: (500, 50, 50, 1)
# Final labels shape: (3000, 50, 50, 1)
# Final data shape: (15358, 50, 50, 1)
# Final labels shape: (15358,)

# %%
counter = Counter(final_labels)
sorted_counts = dict(sorted(counter.items()))
plt.bar(sorted_counts.keys(), sorted_counts.values(), color='skyblue')
plt.grid(True)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Each Class in the Dataset')
plt.xticks(range(3))
plt.show()

# %% [markdown]
# #**Preprocessing**

# %%
data_normalized = final_data / 255

# %%
print(f'Min of original = {np.min(final_data[0])}')
print(f'Max of original = {np.max(final_data[0])}')
print(f'Min of original = {np.min(data_normalized[0])}')
print(f'Max of original = {np.max(data_normalized[0])}')
# Out:
# Min of original = 0
# Max of original = 248
# Min of original = 0.0
# Max of original = 0.9725490196078431

# %%
cropped_flat = final_data.flatten()
normalized_flat = data_normalized.flatten()

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.boxplot(cropped_flat)
plt.title("Original Pixel Values (0-255)")
plt.ylabel("Pixel Intensity")

plt.subplot(1, 2, 2)
plt.boxplot(normalized_flat)
plt.title("Normalized Pixel Values (0-1)")
plt.ylabel("Pixel Intensity")

plt.tight_layout()
plt.show()

# %% [markdown]
# #**Splitting**

# %%
x = data_normalized
y = final_labels
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((10750, 50, 50, 1), (10750,), (4608, 50, 50, 1), (4608,))

# %% [markdown]
# #**CNN**

# %%
model_cnn = keras.Sequential()
model_cnn.add(keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu', input_shape=(50, 50, 1)))
model_cnn.add(keras.layers.MaxPool2D(pool_size=(2, 2)))


model_cnn.add(keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu'))
model_cnn.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))


model_cnn.add(keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu'))
model_cnn.add(keras.layers.MaxPool2D(pool_size=(2, 2)))


model_cnn.add(keras.layers.Flatten())
model_cnn.add(keras.layers.Dense(units=128, activation='relu'))
model_cnn.add(keras.layers.Dropout(0.5))
model_cnn.add(keras.layers.Dense(units=128, activation='relu'))
model_cnn.add(keras.layers.Dropout(0.4))
model_cnn.add(keras.layers.Dense(units=128, activation='relu'))
model_cnn.add(keras.layers.Dropout(0.4))
model_cnn.add(keras.layers.Dense(units=128, activation='relu'))
model_cnn.add(keras.layers.Dropout(0.4))
model_cnn.add(keras.layers.Dense(units=128, activation='relu'))
model_cnn.add(keras.layers.Dropout(0.4))
model_cnn.add(keras.layers.Dense(units=128, activation='relu'))
model_cnn.add(keras.layers.Dropout(0.4))




model_cnn.add(keras.layers.Dense(units=3, activation=keras.activations.softmax))


#Model Compiling
optimizer = keras.optimizers.Adam(learning_rate=0.00001)
loss = keras.losses.SparseCategoricalCrossentropy()
metric = [keras.metrics.CategoricalAccuracy()]

model_cnn.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])


#Builing and Summury
model_cnn.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)                   │ (None, 48, 48, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 22, 22, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 11, 11, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 9, 9, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 4, 4, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 128)                 │         131,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_22 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_23 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_28 (Dense)                     │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_24 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_25 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_30 (Dense)                     │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_26 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_31 (Dense)                     │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_27 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_32 (Dense)                     │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 288,643 (1.10 MB)
#  Trainable params: 288,643 (1.10 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=150, restore_best_weights=True)

# %%
start = time.perf_counter()
hist = model_cnn.fit(x_train, y_train, batch_size=512, epochs=600, validation_data=(x_test, y_test), callbacks=[early_stopping])
end = time.perf_counter()
# Out:
# Epoch 1/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 267ms/step - accuracy: 0.3114 - loss: 1.0990 - val_accuracy: 0.2630 - val_loss: 1.0989
# Epoch 2/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.3253 - loss: 1.0987 - val_accuracy: 0.3012 - val_loss: 1.0986
# Epoch 3/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.3258 - loss: 1.0981 - val_accuracy: 0.4878 - val_loss: 1.0983
# Epoch 4/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.3400 - loss: 1.0983 - val_accuracy: 0.4755 - val_loss: 1.0980
# Epoch 5/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.3520 - loss: 1.0976 - val_accuracy: 0.4820 - val_loss: 1.0977
# Epoch 6/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.3587 - loss: 1.0975 - val_accuracy: 0.4950 - val_loss: 1.0972
# Epoch 7/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.3722 - loss: 1.0963 - val_accuracy: 0.5263 - val_loss: 1.0966
# Epoch 8/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.3786 - loss: 1.0960 - val_accuracy: 0.5579 - val_loss: 1.0958
# Epoch 9/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.3883 - loss: 1.0951 - val_accuracy: 0.6007 - val_loss: 1.0948
# Epoch 10/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4080 - loss: 1.0936 - val_accuracy: 0.6339 - val_loss: 1.0934
# Epoch 11/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4302 - loss: 1.0919 - val_accuracy: 0.6684 - val_loss: 1.0917
# Epoch 12/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.4220 - loss: 1.0898 - val_accuracy: 0.6914 - val_loss: 1.0893
# Epoch 13/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.4332 - loss: 1.0861 - val_accuracy: 0.6812 - val_loss: 1.0859
# Epoch 14/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.4330 - loss: 1.0816 - val_accuracy: 0.6667 - val_loss: 1.0814
# Epoch 15/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.4512 - loss: 1.0756 - val_accuracy: 0.6491 - val_loss: 1.0750
# Epoch 16/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4620 - loss: 1.0675 - val_accuracy: 0.6311 - val_loss: 1.0664
# Epoch 17/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4753 - loss: 1.0574 - val_accuracy: 0.6239 - val_loss: 1.0550
# Epoch 18/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.5239 - loss: 1.0429 - val_accuracy: 0.6272 - val_loss: 1.0403
# Epoch 19/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.5566 - loss: 1.0275 - val_accuracy: 0.6265 - val_loss: 1.0224
# Epoch 20/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.5981 - loss: 1.0050 - val_accuracy: 0.6439 - val_loss: 1.0029
# Epoch 21/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6132 - loss: 0.9895 - val_accuracy: 0.6643 - val_loss: 0.9850
# Epoch 22/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.6277 - loss: 0.9767 - val_accuracy: 0.6714 - val_loss: 0.9680
# Epoch 23/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6433 - loss: 0.9604 - val_accuracy: 0.6756 - val_loss: 0.9547
# Epoch 24/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6554 - loss: 0.9466 - val_accuracy: 0.6812 - val_loss: 0.9426
# Epoch 25/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6592 - loss: 0.9435 - val_accuracy: 0.6890 - val_loss: 0.9340
# Epoch 26/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6627 - loss: 0.9332 - val_accuracy: 0.6923 - val_loss: 0.9259
# Epoch 27/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6651 - loss: 0.9314 - val_accuracy: 0.6966 - val_loss: 0.9205
# Epoch 28/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6732 - loss: 0.9293 - val_accuracy: 0.7003 - val_loss: 0.9153
# Epoch 29/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6763 - loss: 0.9218 - val_accuracy: 0.7051 - val_loss: 0.9098
# Epoch 30/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6765 - loss: 0.9184 - val_accuracy: 0.7079 - val_loss: 0.9061
# Epoch 31/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6795 - loss: 0.9177 - val_accuracy: 0.7135 - val_loss: 0.9020
# Epoch 32/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6990 - loss: 0.9046 - val_accuracy: 0.7148 - val_loss: 0.8982
# Epoch 33/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6966 - loss: 0.9027 - val_accuracy: 0.7181 - val_loss: 0.8959
# Epoch 34/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6973 - loss: 0.9051 - val_accuracy: 0.7240 - val_loss: 0.8936
# Epoch 35/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6959 - loss: 0.9087 - val_accuracy: 0.7294 - val_loss: 0.8913
# Epoch 36/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7002 - loss: 0.9063 - val_accuracy: 0.7348 - val_loss: 0.8876
# Epoch 37/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6973 - loss: 0.9039 - val_accuracy: 0.7363 - val_loss: 0.8853
# Epoch 38/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7147 - loss: 0.8973 - val_accuracy: 0.7396 - val_loss: 0.8825
# Epoch 39/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7102 - loss: 0.8987 - val_accuracy: 0.7424 - val_loss: 0.8804
# Epoch 40/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7119 - loss: 0.8945 - val_accuracy: 0.7457 - val_loss: 0.8774
# Epoch 41/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7127 - loss: 0.8948 - val_accuracy: 0.7431 - val_loss: 0.8752
# Epoch 42/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7183 - loss: 0.8832 - val_accuracy: 0.7465 - val_loss: 0.8724
# Epoch 43/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7135 - loss: 0.8844 - val_accuracy: 0.7489 - val_loss: 0.8705
# Epoch 44/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7248 - loss: 0.8815 - val_accuracy: 0.7513 - val_loss: 0.8680
# Epoch 45/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7170 - loss: 0.8833 - val_accuracy: 0.7524 - val_loss: 0.8670
# Epoch 46/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7219 - loss: 0.8787 - val_accuracy: 0.7574 - val_loss: 0.8630
# Epoch 47/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7245 - loss: 0.8776 - val_accuracy: 0.7500 - val_loss: 0.8626
# Epoch 48/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7198 - loss: 0.8836 - val_accuracy: 0.7580 - val_loss: 0.8598
# Epoch 49/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7299 - loss: 0.8737 - val_accuracy: 0.7604 - val_loss: 0.8567
# Epoch 50/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7293 - loss: 0.8699 - val_accuracy: 0.7606 - val_loss: 0.8552
# Epoch 51/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7250 - loss: 0.8709 - val_accuracy: 0.7645 - val_loss: 0.8526
# Epoch 52/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7293 - loss: 0.8692 - val_accuracy: 0.7619 - val_loss: 0.8512
# Epoch 53/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7374 - loss: 0.8699 - val_accuracy: 0.7669 - val_loss: 0.8482
# Epoch 54/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7285 - loss: 0.8730 - val_accuracy: 0.7676 - val_loss: 0.8474
# Epoch 55/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7288 - loss: 0.8607 - val_accuracy: 0.7676 - val_loss: 0.8442
# Epoch 56/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7344 - loss: 0.8568 - val_accuracy: 0.7676 - val_loss: 0.8438
# Epoch 57/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7359 - loss: 0.8606 - val_accuracy: 0.7704 - val_loss: 0.8427
# Epoch 58/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7309 - loss: 0.8487 - val_accuracy: 0.7715 - val_loss: 0.8384
# Epoch 59/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7401 - loss: 0.8548 - val_accuracy: 0.7719 - val_loss: 0.8353
# Epoch 60/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7254 - loss: 0.8555 - val_accuracy: 0.7689 - val_loss: 0.8335
# Epoch 61/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7342 - loss: 0.8548 - val_accuracy: 0.7667 - val_loss: 0.8320
# Epoch 62/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7378 - loss: 0.8432 - val_accuracy: 0.7717 - val_loss: 0.8276
# Epoch 63/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7302 - loss: 0.8481 - val_accuracy: 0.7682 - val_loss: 0.8267
# Epoch 64/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7332 - loss: 0.8495 - val_accuracy: 0.7695 - val_loss: 0.8242
# Epoch 65/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7288 - loss: 0.8452 - val_accuracy: 0.7708 - val_loss: 0.8212
# Epoch 66/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7342 - loss: 0.8480 - val_accuracy: 0.7750 - val_loss: 0.8205
# Epoch 67/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7444 - loss: 0.8308 - val_accuracy: 0.7763 - val_loss: 0.8172
# Epoch 68/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7357 - loss: 0.8405 - val_accuracy: 0.7741 - val_loss: 0.8160
# Epoch 69/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7331 - loss: 0.8355 - val_accuracy: 0.7778 - val_loss: 0.8121
# Epoch 70/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7358 - loss: 0.8330 - val_accuracy: 0.7747 - val_loss: 0.8098
# Epoch 71/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7316 - loss: 0.8327 - val_accuracy: 0.7769 - val_loss: 0.8075
# Epoch 72/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7319 - loss: 0.8320 - val_accuracy: 0.7810 - val_loss: 0.8043
# Epoch 73/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7343 - loss: 0.8217 - val_accuracy: 0.7778 - val_loss: 0.8025
# Epoch 74/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7371 - loss: 0.8305 - val_accuracy: 0.7795 - val_loss: 0.8014
# Epoch 75/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7477 - loss: 0.8176 - val_accuracy: 0.7782 - val_loss: 0.7987
# Epoch 76/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7389 - loss: 0.8128 - val_accuracy: 0.7799 - val_loss: 0.7951
# Epoch 77/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7370 - loss: 0.8059 - val_accuracy: 0.7823 - val_loss: 0.7912
# Epoch 78/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7385 - loss: 0.8151 - val_accuracy: 0.7799 - val_loss: 0.7893
# Epoch 79/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7443 - loss: 0.8076 - val_accuracy: 0.7819 - val_loss: 0.7866
# Epoch 80/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7366 - loss: 0.8110 - val_accuracy: 0.7830 - val_loss: 0.7836
# Epoch 81/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7417 - loss: 0.8081 - val_accuracy: 0.7817 - val_loss: 0.7812
# Epoch 82/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7483 - loss: 0.7987 - val_accuracy: 0.7826 - val_loss: 0.7784
# Epoch 83/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7312 - loss: 0.7980 - val_accuracy: 0.7819 - val_loss: 0.7754
# Epoch 84/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7381 - loss: 0.7986 - val_accuracy: 0.7845 - val_loss: 0.7718
# Epoch 85/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7440 - loss: 0.7978 - val_accuracy: 0.7828 - val_loss: 0.7698
# Epoch 86/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7374 - loss: 0.7935 - val_accuracy: 0.7858 - val_loss: 0.7660
# Epoch 87/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7437 - loss: 0.7936 - val_accuracy: 0.7841 - val_loss: 0.7624
# Epoch 88/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.7338 - loss: 0.7929 - val_accuracy: 0.7821 - val_loss: 0.7606
# Epoch 89/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.7426 - loss: 0.7789 - val_accuracy: 0.7852 - val_loss: 0.7533
# Epoch 90/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7460 - loss: 0.7791 - val_accuracy: 0.7854 - val_loss: 0.7532
# Epoch 91/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7448 - loss: 0.7834 - val_accuracy: 0.7832 - val_loss: 0.7519
# Epoch 92/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7384 - loss: 0.7749 - val_accuracy: 0.7880 - val_loss: 0.7465
# Epoch 93/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7484 - loss: 0.7770 - val_accuracy: 0.7882 - val_loss: 0.7428
# Epoch 94/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7408 - loss: 0.7691 - val_accuracy: 0.7908 - val_loss: 0.7395
# Epoch 95/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7441 - loss: 0.7664 - val_accuracy: 0.7899 - val_loss: 0.7367
# Epoch 96/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7506 - loss: 0.7564 - val_accuracy: 0.7906 - val_loss: 0.7310
# Epoch 97/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7466 - loss: 0.7639 - val_accuracy: 0.7895 - val_loss: 0.7286
# Epoch 98/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7390 - loss: 0.7620 - val_accuracy: 0.7899 - val_loss: 0.7244
# Epoch 99/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7408 - loss: 0.7612 - val_accuracy: 0.7893 - val_loss: 0.7215
# Epoch 100/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7409 - loss: 0.7538 - val_accuracy: 0.7854 - val_loss: 0.7199
# Epoch 101/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7507 - loss: 0.7509 - val_accuracy: 0.7901 - val_loss: 0.7140
# Epoch 102/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7498 - loss: 0.7507 - val_accuracy: 0.7893 - val_loss: 0.7112
# Epoch 103/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7490 - loss: 0.7443 - val_accuracy: 0.7856 - val_loss: 0.7087
# Epoch 104/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7443 - loss: 0.7425 - val_accuracy: 0.7901 - val_loss: 0.7036
# Epoch 105/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7490 - loss: 0.7436 - val_accuracy: 0.7912 - val_loss: 0.6992
# Epoch 106/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7514 - loss: 0.7322 - val_accuracy: 0.7854 - val_loss: 0.6979
# Epoch 107/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7541 - loss: 0.7239 - val_accuracy: 0.7906 - val_loss: 0.6904
# Epoch 108/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7538 - loss: 0.7256 - val_accuracy: 0.7928 - val_loss: 0.6861
# Epoch 109/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7531 - loss: 0.7219 - val_accuracy: 0.7880 - val_loss: 0.6848
# Epoch 110/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.7526 - loss: 0.7281 - val_accuracy: 0.7882 - val_loss: 0.6817
# Epoch 111/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7490 - loss: 0.7120 - val_accuracy: 0.7852 - val_loss: 0.6789
# Epoch 112/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7501 - loss: 0.7094 - val_accuracy: 0.7895 - val_loss: 0.6733
# Epoch 113/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7533 - loss: 0.7214 - val_accuracy: 0.7910 - val_loss: 0.6671
# Epoch 114/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7518 - loss: 0.7079 - val_accuracy: 0.7847 - val_loss: 0.6666
# Epoch 115/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7551 - loss: 0.7100 - val_accuracy: 0.7893 - val_loss: 0.6616
# Epoch 116/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7504 - loss: 0.7051 - val_accuracy: 0.7856 - val_loss: 0.6585
# Epoch 117/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7593 - loss: 0.6989 - val_accuracy: 0.7862 - val_loss: 0.6544
# Epoch 118/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7531 - loss: 0.6959 - val_accuracy: 0.7891 - val_loss: 0.6494
# Epoch 119/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7596 - loss: 0.6895 - val_accuracy: 0.7854 - val_loss: 0.6473
# Epoch 120/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7544 - loss: 0.6808 - val_accuracy: 0.7928 - val_loss: 0.6382
# Epoch 121/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7578 - loss: 0.6836 - val_accuracy: 0.7841 - val_loss: 0.6401
# Epoch 122/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7499 - loss: 0.6837 - val_accuracy: 0.7880 - val_loss: 0.6339
# Epoch 123/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7599 - loss: 0.6782 - val_accuracy: 0.7906 - val_loss: 0.6294
# Epoch 124/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7529 - loss: 0.6755 - val_accuracy: 0.7897 - val_loss: 0.6255
# Epoch 125/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7560 - loss: 0.6670 - val_accuracy: 0.7865 - val_loss: 0.6233
# Epoch 126/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7630 - loss: 0.6695 - val_accuracy: 0.7891 - val_loss: 0.6176
# Epoch 127/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7626 - loss: 0.6677 - val_accuracy: 0.7910 - val_loss: 0.6137
# Epoch 128/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7608 - loss: 0.6579 - val_accuracy: 0.7843 - val_loss: 0.6149
# Epoch 129/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7680 - loss: 0.6599 - val_accuracy: 0.7871 - val_loss: 0.6099
# Epoch 130/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7567 - loss: 0.6686 - val_accuracy: 0.7891 - val_loss: 0.6045
# Epoch 131/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.7610 - loss: 0.6496 - val_accuracy: 0.7858 - val_loss: 0.6034
# Epoch 132/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7661 - loss: 0.6580 - val_accuracy: 0.7945 - val_loss: 0.5941
# Epoch 133/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7699 - loss: 0.6471 - val_accuracy: 0.7897 - val_loss: 0.5945
# Epoch 134/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7665 - loss: 0.6382 - val_accuracy: 0.7886 - val_loss: 0.5917
# Epoch 135/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7599 - loss: 0.6481 - val_accuracy: 0.7958 - val_loss: 0.5834
# Epoch 136/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7601 - loss: 0.6437 - val_accuracy: 0.7880 - val_loss: 0.5866
# Epoch 137/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7641 - loss: 0.6392 - val_accuracy: 0.7928 - val_loss: 0.5804
# Epoch 138/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7636 - loss: 0.6344 - val_accuracy: 0.7904 - val_loss: 0.5790
# Epoch 139/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7606 - loss: 0.6340 - val_accuracy: 0.7936 - val_loss: 0.5739
# Epoch 140/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7702 - loss: 0.6306 - val_accuracy: 0.7943 - val_loss: 0.5703
# Epoch 141/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.7726 - loss: 0.6177 - val_accuracy: 0.7949 - val_loss: 0.5665
# Epoch 142/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7706 - loss: 0.6239 - val_accuracy: 0.7917 - val_loss: 0.5678
# Epoch 143/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7716 - loss: 0.6090 - val_accuracy: 0.7958 - val_loss: 0.5604
# Epoch 144/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7667 - loss: 0.6205 - val_accuracy: 0.7967 - val_loss: 0.5568
# Epoch 145/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7716 - loss: 0.6125 - val_accuracy: 0.7886 - val_loss: 0.5645
# Epoch 146/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7724 - loss: 0.6197 - val_accuracy: 0.7954 - val_loss: 0.5549
# Epoch 147/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7735 - loss: 0.6040 - val_accuracy: 0.7956 - val_loss: 0.5523
# Epoch 148/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7809 - loss: 0.5969 - val_accuracy: 0.7956 - val_loss: 0.5493
# Epoch 149/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7748 - loss: 0.6036 - val_accuracy: 0.7977 - val_loss: 0.5437
# Epoch 150/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7787 - loss: 0.6023 - val_accuracy: 0.7936 - val_loss: 0.5471
# Epoch 151/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7793 - loss: 0.6018 - val_accuracy: 0.7986 - val_loss: 0.5392
# Epoch 152/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.7701 - loss: 0.6039 - val_accuracy: 0.7977 - val_loss: 0.5385
# Epoch 153/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7835 - loss: 0.5895 - val_accuracy: 0.7971 - val_loss: 0.5377
# Epoch 154/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7785 - loss: 0.6047 - val_accuracy: 0.8008 - val_loss: 0.5322
# Epoch 155/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7853 - loss: 0.5896 - val_accuracy: 0.8001 - val_loss: 0.5294
# Epoch 156/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7809 - loss: 0.5867 - val_accuracy: 0.7969 - val_loss: 0.5321
# Epoch 157/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7792 - loss: 0.5974 - val_accuracy: 0.7973 - val_loss: 0.5304
# Epoch 158/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7873 - loss: 0.5768 - val_accuracy: 0.7977 - val_loss: 0.5277
# Epoch 159/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7880 - loss: 0.5736 - val_accuracy: 0.8056 - val_loss: 0.5196
# Epoch 160/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7842 - loss: 0.5853 - val_accuracy: 0.8014 - val_loss: 0.5214
# Epoch 161/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7789 - loss: 0.5885 - val_accuracy: 0.8038 - val_loss: 0.5180
# Epoch 162/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7903 - loss: 0.5824 - val_accuracy: 0.8001 - val_loss: 0.5199
# Epoch 163/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.7893 - loss: 0.5718 - val_accuracy: 0.8071 - val_loss: 0.5128
# Epoch 164/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7788 - loss: 0.5811 - val_accuracy: 0.8032 - val_loss: 0.5155
# Epoch 165/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7795 - loss: 0.5764 - val_accuracy: 0.8064 - val_loss: 0.5120
# Epoch 166/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7898 - loss: 0.5741 - val_accuracy: 0.8079 - val_loss: 0.5086
# Epoch 167/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7855 - loss: 0.5797 - val_accuracy: 0.8088 - val_loss: 0.5069
# Epoch 168/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7936 - loss: 0.5596 - val_accuracy: 0.8086 - val_loss: 0.5053
# Epoch 169/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7913 - loss: 0.5644 - val_accuracy: 0.8103 - val_loss: 0.5027
# Epoch 170/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7942 - loss: 0.5485 - val_accuracy: 0.8114 - val_loss: 0.5013
# Epoch 171/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7902 - loss: 0.5667 - val_accuracy: 0.8095 - val_loss: 0.5019
# Epoch 172/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7931 - loss: 0.5602 - val_accuracy: 0.8142 - val_loss: 0.4946
# Epoch 173/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7933 - loss: 0.5687 - val_accuracy: 0.8060 - val_loss: 0.5037
# Epoch 174/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7921 - loss: 0.5521 - val_accuracy: 0.8110 - val_loss: 0.4968
# Epoch 175/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7876 - loss: 0.5651 - val_accuracy: 0.8116 - val_loss: 0.4968
# Epoch 176/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7908 - loss: 0.5628 - val_accuracy: 0.8090 - val_loss: 0.4976
# Epoch 177/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7935 - loss: 0.5557 - val_accuracy: 0.8151 - val_loss: 0.4883
# Epoch 178/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7963 - loss: 0.5519 - val_accuracy: 0.8147 - val_loss: 0.4882
# Epoch 179/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7971 - loss: 0.5521 - val_accuracy: 0.8166 - val_loss: 0.4853
# Epoch 180/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7852 - loss: 0.5743 - val_accuracy: 0.8166 - val_loss: 0.4855
# Epoch 181/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7940 - loss: 0.5602 - val_accuracy: 0.8145 - val_loss: 0.4869
# Epoch 182/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7903 - loss: 0.5581 - val_accuracy: 0.8166 - val_loss: 0.4849
# Epoch 183/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7890 - loss: 0.5617 - val_accuracy: 0.8177 - val_loss: 0.4835
# Epoch 184/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7865 - loss: 0.5628 - val_accuracy: 0.8201 - val_loss: 0.4788
# Epoch 185/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.7906 - loss: 0.5520 - val_accuracy: 0.8127 - val_loss: 0.4887
# Epoch 186/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8000 - loss: 0.5449 - val_accuracy: 0.8166 - val_loss: 0.4803
# Epoch 187/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7973 - loss: 0.5521 - val_accuracy: 0.8201 - val_loss: 0.4771
# Epoch 188/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8075 - loss: 0.5395 - val_accuracy: 0.8168 - val_loss: 0.4813
# Epoch 189/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8037 - loss: 0.5328 - val_accuracy: 0.8220 - val_loss: 0.4733
# Epoch 190/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7955 - loss: 0.5450 - val_accuracy: 0.8194 - val_loss: 0.4770
# Epoch 191/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7984 - loss: 0.5380 - val_accuracy: 0.8181 - val_loss: 0.4769
# Epoch 192/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8007 - loss: 0.5364 - val_accuracy: 0.8177 - val_loss: 0.4766
# Epoch 193/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8028 - loss: 0.5357 - val_accuracy: 0.8199 - val_loss: 0.4733
# Epoch 194/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7990 - loss: 0.5294 - val_accuracy: 0.8236 - val_loss: 0.4689
# Epoch 195/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8000 - loss: 0.5365 - val_accuracy: 0.8194 - val_loss: 0.4718
# Epoch 196/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8043 - loss: 0.5278 - val_accuracy: 0.8223 - val_loss: 0.4701
# Epoch 197/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8092 - loss: 0.5296 - val_accuracy: 0.8273 - val_loss: 0.4630
# Epoch 198/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8007 - loss: 0.5368 - val_accuracy: 0.8262 - val_loss: 0.4647
# Epoch 199/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8129 - loss: 0.5270 - val_accuracy: 0.8214 - val_loss: 0.4704
# Epoch 200/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7987 - loss: 0.5422 - val_accuracy: 0.8279 - val_loss: 0.4621
# Epoch 201/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8070 - loss: 0.5198 - val_accuracy: 0.8264 - val_loss: 0.4648
# Epoch 202/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8117 - loss: 0.5142 - val_accuracy: 0.8283 - val_loss: 0.4629
# Epoch 203/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8068 - loss: 0.5207 - val_accuracy: 0.8257 - val_loss: 0.4632
# Epoch 204/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8091 - loss: 0.5253 - val_accuracy: 0.8292 - val_loss: 0.4593
# Epoch 205/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8167 - loss: 0.5195 - val_accuracy: 0.8253 - val_loss: 0.4643
# Epoch 206/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8079 - loss: 0.5250 - val_accuracy: 0.8292 - val_loss: 0.4588
# Epoch 207/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8115 - loss: 0.5210 - val_accuracy: 0.8266 - val_loss: 0.4606
# Epoch 208/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8102 - loss: 0.5070 - val_accuracy: 0.8270 - val_loss: 0.4605
# Epoch 209/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8044 - loss: 0.5194 - val_accuracy: 0.8279 - val_loss: 0.4619
# Epoch 210/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8132 - loss: 0.5185 - val_accuracy: 0.8312 - val_loss: 0.4548
# Epoch 211/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8125 - loss: 0.5111 - val_accuracy: 0.8273 - val_loss: 0.4599
# Epoch 212/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8117 - loss: 0.5167 - val_accuracy: 0.8296 - val_loss: 0.4549
# Epoch 213/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8043 - loss: 0.5209 - val_accuracy: 0.8266 - val_loss: 0.4605
# Epoch 214/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8074 - loss: 0.5181 - val_accuracy: 0.8322 - val_loss: 0.4499
# Epoch 215/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8042 - loss: 0.5202 - val_accuracy: 0.8314 - val_loss: 0.4520
# Epoch 216/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8110 - loss: 0.5257 - val_accuracy: 0.8279 - val_loss: 0.4590
# Epoch 217/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8178 - loss: 0.5065 - val_accuracy: 0.8314 - val_loss: 0.4502
# Epoch 218/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8159 - loss: 0.5133 - val_accuracy: 0.8322 - val_loss: 0.4495
# Epoch 219/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8176 - loss: 0.5140 - val_accuracy: 0.8305 - val_loss: 0.4544
# Epoch 220/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8101 - loss: 0.5191 - val_accuracy: 0.8266 - val_loss: 0.4631
# Epoch 221/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8111 - loss: 0.5131 - val_accuracy: 0.8316 - val_loss: 0.4513
# Epoch 222/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8175 - loss: 0.5091 - val_accuracy: 0.8316 - val_loss: 0.4496
# Epoch 223/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8050 - loss: 0.5195 - val_accuracy: 0.8312 - val_loss: 0.4536
# Epoch 224/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8095 - loss: 0.5083 - val_accuracy: 0.8342 - val_loss: 0.4462
# Epoch 225/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8185 - loss: 0.5018 - val_accuracy: 0.8307 - val_loss: 0.4545
# Epoch 226/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8187 - loss: 0.5052 - val_accuracy: 0.8325 - val_loss: 0.4496
# Epoch 227/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8181 - loss: 0.4972 - val_accuracy: 0.8342 - val_loss: 0.4468
# Epoch 228/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8117 - loss: 0.5175 - val_accuracy: 0.8336 - val_loss: 0.4472
# Epoch 229/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8161 - loss: 0.5045 - val_accuracy: 0.8320 - val_loss: 0.4532
# Epoch 230/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8121 - loss: 0.5087 - val_accuracy: 0.8344 - val_loss: 0.4457
# Epoch 231/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8251 - loss: 0.4868 - val_accuracy: 0.8381 - val_loss: 0.4404
# Epoch 232/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8138 - loss: 0.5049 - val_accuracy: 0.8340 - val_loss: 0.4469
# Epoch 233/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8195 - loss: 0.4942 - val_accuracy: 0.8355 - val_loss: 0.4420
# Epoch 234/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8279 - loss: 0.4837 - val_accuracy: 0.8340 - val_loss: 0.4455
# Epoch 235/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8118 - loss: 0.5066 - val_accuracy: 0.8364 - val_loss: 0.4392
# Epoch 236/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8273 - loss: 0.4843 - val_accuracy: 0.8362 - val_loss: 0.4436
# Epoch 237/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8176 - loss: 0.4989 - val_accuracy: 0.8368 - val_loss: 0.4399
# Epoch 238/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8171 - loss: 0.4993 - val_accuracy: 0.8355 - val_loss: 0.4493
# Epoch 239/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8217 - loss: 0.4930 - val_accuracy: 0.8353 - val_loss: 0.4413
# Epoch 240/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8244 - loss: 0.4854 - val_accuracy: 0.8353 - val_loss: 0.4462
# Epoch 241/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8223 - loss: 0.4849 - val_accuracy: 0.8398 - val_loss: 0.4366
# Epoch 242/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8227 - loss: 0.4886 - val_accuracy: 0.8370 - val_loss: 0.4414
# Epoch 243/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8248 - loss: 0.5004 - val_accuracy: 0.8370 - val_loss: 0.4412
# Epoch 244/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8263 - loss: 0.4765 - val_accuracy: 0.8375 - val_loss: 0.4403
# Epoch 245/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8162 - loss: 0.5043 - val_accuracy: 0.8379 - val_loss: 0.4401
# Epoch 246/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8260 - loss: 0.4843 - val_accuracy: 0.8388 - val_loss: 0.4386
# Epoch 247/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8196 - loss: 0.4994 - val_accuracy: 0.8416 - val_loss: 0.4340
# Epoch 248/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8253 - loss: 0.4948 - val_accuracy: 0.8370 - val_loss: 0.4438
# Epoch 249/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8229 - loss: 0.4964 - val_accuracy: 0.8420 - val_loss: 0.4348
# Epoch 250/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8287 - loss: 0.4855 - val_accuracy: 0.8411 - val_loss: 0.4371
# Epoch 251/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8182 - loss: 0.4923 - val_accuracy: 0.8418 - val_loss: 0.4361
# Epoch 252/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8213 - loss: 0.4902 - val_accuracy: 0.8383 - val_loss: 0.4404
# Epoch 253/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8238 - loss: 0.4783 - val_accuracy: 0.8420 - val_loss: 0.4350
# Epoch 254/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8185 - loss: 0.4930 - val_accuracy: 0.8377 - val_loss: 0.4430
# Epoch 255/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8324 - loss: 0.4860 - val_accuracy: 0.8435 - val_loss: 0.4306
# Epoch 256/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8228 - loss: 0.4938 - val_accuracy: 0.8429 - val_loss: 0.4324
# Epoch 257/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8230 - loss: 0.4903 - val_accuracy: 0.8385 - val_loss: 0.4419
# Epoch 258/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8267 - loss: 0.4847 - val_accuracy: 0.8435 - val_loss: 0.4333
# Epoch 259/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8290 - loss: 0.4806 - val_accuracy: 0.8442 - val_loss: 0.4351
# Epoch 260/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8323 - loss: 0.4636 - val_accuracy: 0.8422 - val_loss: 0.4368
# Epoch 261/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8362 - loss: 0.4643 - val_accuracy: 0.8416 - val_loss: 0.4363
# Epoch 262/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8205 - loss: 0.4901 - val_accuracy: 0.8405 - val_loss: 0.4375
# Epoch 263/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8324 - loss: 0.4740 - val_accuracy: 0.8446 - val_loss: 0.4307
# Epoch 264/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8226 - loss: 0.4872 - val_accuracy: 0.8427 - val_loss: 0.4344
# Epoch 265/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8251 - loss: 0.4808 - val_accuracy: 0.8427 - val_loss: 0.4365
# Epoch 266/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8310 - loss: 0.4752 - val_accuracy: 0.8461 - val_loss: 0.4279
# Epoch 267/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8225 - loss: 0.4812 - val_accuracy: 0.8418 - val_loss: 0.4371
# Epoch 268/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8269 - loss: 0.4904 - val_accuracy: 0.8440 - val_loss: 0.4298
# Epoch 269/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8207 - loss: 0.4961 - val_accuracy: 0.8448 - val_loss: 0.4299
# Epoch 270/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8285 - loss: 0.4754 - val_accuracy: 0.8444 - val_loss: 0.4306
# Epoch 271/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8272 - loss: 0.4782 - val_accuracy: 0.8420 - val_loss: 0.4356
# Epoch 272/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8268 - loss: 0.4768 - val_accuracy: 0.8464 - val_loss: 0.4280
# Epoch 273/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8340 - loss: 0.4671 - val_accuracy: 0.8424 - val_loss: 0.4351
# Epoch 274/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8265 - loss: 0.4811 - val_accuracy: 0.8453 - val_loss: 0.4301
# Epoch 275/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8304 - loss: 0.4764 - val_accuracy: 0.8435 - val_loss: 0.4347
# Epoch 276/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8297 - loss: 0.4735 - val_accuracy: 0.8466 - val_loss: 0.4277
# Epoch 277/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8359 - loss: 0.4706 - val_accuracy: 0.8468 - val_loss: 0.4275
# Epoch 278/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8277 - loss: 0.4859 - val_accuracy: 0.8446 - val_loss: 0.4318
# Epoch 279/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8332 - loss: 0.4724 - val_accuracy: 0.8466 - val_loss: 0.4295
# Epoch 280/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8369 - loss: 0.4749 - val_accuracy: 0.8446 - val_loss: 0.4312
# Epoch 281/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8297 - loss: 0.4733 - val_accuracy: 0.8431 - val_loss: 0.4341
# Epoch 282/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8334 - loss: 0.4661 - val_accuracy: 0.8479 - val_loss: 0.4262
# Epoch 283/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8320 - loss: 0.4664 - val_accuracy: 0.8448 - val_loss: 0.4316
# Epoch 284/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8330 - loss: 0.4711 - val_accuracy: 0.8438 - val_loss: 0.4361
# Epoch 285/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8322 - loss: 0.4760 - val_accuracy: 0.8479 - val_loss: 0.4261
# Epoch 286/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8265 - loss: 0.4818 - val_accuracy: 0.8470 - val_loss: 0.4290
# Epoch 287/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8318 - loss: 0.4749 - val_accuracy: 0.8472 - val_loss: 0.4280
# Epoch 288/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8205 - loss: 0.4823 - val_accuracy: 0.8448 - val_loss: 0.4346
# Epoch 289/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8275 - loss: 0.4779 - val_accuracy: 0.8455 - val_loss: 0.4329
# Epoch 290/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8271 - loss: 0.4785 - val_accuracy: 0.8481 - val_loss: 0.4264
# Epoch 291/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8404 - loss: 0.4634 - val_accuracy: 0.8461 - val_loss: 0.4316
# Epoch 292/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8255 - loss: 0.4780 - val_accuracy: 0.8470 - val_loss: 0.4278
# Epoch 293/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8338 - loss: 0.4602 - val_accuracy: 0.8490 - val_loss: 0.4231
# Epoch 294/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8370 - loss: 0.4672 - val_accuracy: 0.8461 - val_loss: 0.4317
# Epoch 295/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8393 - loss: 0.4587 - val_accuracy: 0.8468 - val_loss: 0.4280
# Epoch 296/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8321 - loss: 0.4694 - val_accuracy: 0.8461 - val_loss: 0.4297
# Epoch 297/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8296 - loss: 0.4761 - val_accuracy: 0.8470 - val_loss: 0.4295
# Epoch 298/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8281 - loss: 0.4674 - val_accuracy: 0.8485 - val_loss: 0.4265
# Epoch 299/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8332 - loss: 0.4682 - val_accuracy: 0.8477 - val_loss: 0.4259
# Epoch 300/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8331 - loss: 0.4585 - val_accuracy: 0.8487 - val_loss: 0.4263
# Epoch 301/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8376 - loss: 0.4553 - val_accuracy: 0.8490 - val_loss: 0.4216
# Epoch 302/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8305 - loss: 0.4692 - val_accuracy: 0.8466 - val_loss: 0.4292
# Epoch 303/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8416 - loss: 0.4532 - val_accuracy: 0.8496 - val_loss: 0.4261
# Epoch 304/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8306 - loss: 0.4687 - val_accuracy: 0.8487 - val_loss: 0.4241
# Epoch 305/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8359 - loss: 0.4649 - val_accuracy: 0.8490 - val_loss: 0.4264
# Epoch 306/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8389 - loss: 0.4533 - val_accuracy: 0.8485 - val_loss: 0.4247
# Epoch 307/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8347 - loss: 0.4665 - val_accuracy: 0.8487 - val_loss: 0.4246
# Epoch 308/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8362 - loss: 0.4729 - val_accuracy: 0.8479 - val_loss: 0.4219
# Epoch 309/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8363 - loss: 0.4619 - val_accuracy: 0.8464 - val_loss: 0.4287
# Epoch 310/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8343 - loss: 0.4503 - val_accuracy: 0.8483 - val_loss: 0.4233
# Epoch 311/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8331 - loss: 0.4620 - val_accuracy: 0.8444 - val_loss: 0.4335
# Epoch 312/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8355 - loss: 0.4652 - val_accuracy: 0.8494 - val_loss: 0.4232
# Epoch 313/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8330 - loss: 0.4658 - val_accuracy: 0.8481 - val_loss: 0.4253
# Epoch 314/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8373 - loss: 0.4534 - val_accuracy: 0.8487 - val_loss: 0.4246
# Epoch 315/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8346 - loss: 0.4644 - val_accuracy: 0.8496 - val_loss: 0.4245
# Epoch 316/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8402 - loss: 0.4551 - val_accuracy: 0.8466 - val_loss: 0.4295
# Epoch 317/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8360 - loss: 0.4552 - val_accuracy: 0.8513 - val_loss: 0.4181
# Epoch 318/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8327 - loss: 0.4693 - val_accuracy: 0.8468 - val_loss: 0.4258
# Epoch 319/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8384 - loss: 0.4540 - val_accuracy: 0.8520 - val_loss: 0.4204
# Epoch 320/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8373 - loss: 0.4521 - val_accuracy: 0.8490 - val_loss: 0.4239
# Epoch 321/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8447 - loss: 0.4496 - val_accuracy: 0.8496 - val_loss: 0.4232
# Epoch 322/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8390 - loss: 0.4499 - val_accuracy: 0.8503 - val_loss: 0.4226
# Epoch 323/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8376 - loss: 0.4594 - val_accuracy: 0.8509 - val_loss: 0.4172
# Epoch 324/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8351 - loss: 0.4600 - val_accuracy: 0.8487 - val_loss: 0.4245
# Epoch 325/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8374 - loss: 0.4539 - val_accuracy: 0.8481 - val_loss: 0.4245
# Epoch 326/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8338 - loss: 0.4664 - val_accuracy: 0.8511 - val_loss: 0.4202
# Epoch 327/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8406 - loss: 0.4489 - val_accuracy: 0.8520 - val_loss: 0.4198
# Epoch 328/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8356 - loss: 0.4584 - val_accuracy: 0.8485 - val_loss: 0.4219
# Epoch 329/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8409 - loss: 0.4504 - val_accuracy: 0.8485 - val_loss: 0.4230
# Epoch 330/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8338 - loss: 0.4620 - val_accuracy: 0.8494 - val_loss: 0.4201
# Epoch 331/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8402 - loss: 0.4461 - val_accuracy: 0.8518 - val_loss: 0.4164
# Epoch 332/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8378 - loss: 0.4549 - val_accuracy: 0.8477 - val_loss: 0.4255
# Epoch 333/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8374 - loss: 0.4529 - val_accuracy: 0.8509 - val_loss: 0.4199
# Epoch 334/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8431 - loss: 0.4498 - val_accuracy: 0.8494 - val_loss: 0.4238
# Epoch 335/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8424 - loss: 0.4435 - val_accuracy: 0.8492 - val_loss: 0.4229
# Epoch 336/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8424 - loss: 0.4450 - val_accuracy: 0.8507 - val_loss: 0.4210
# Epoch 337/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8446 - loss: 0.4421 - val_accuracy: 0.8505 - val_loss: 0.4200
# Epoch 338/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8436 - loss: 0.4437 - val_accuracy: 0.8498 - val_loss: 0.4203
# Epoch 339/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8347 - loss: 0.4556 - val_accuracy: 0.8526 - val_loss: 0.4160
# Epoch 340/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8394 - loss: 0.4476 - val_accuracy: 0.8496 - val_loss: 0.4236
# Epoch 341/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8367 - loss: 0.4614 - val_accuracy: 0.8513 - val_loss: 0.4196
# Epoch 342/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8395 - loss: 0.4437 - val_accuracy: 0.8498 - val_loss: 0.4225
# Epoch 343/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8419 - loss: 0.4447 - val_accuracy: 0.8492 - val_loss: 0.4205
# Epoch 344/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8393 - loss: 0.4555 - val_accuracy: 0.8537 - val_loss: 0.4117
# Epoch 345/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8423 - loss: 0.4442 - val_accuracy: 0.8513 - val_loss: 0.4186
# Epoch 346/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8448 - loss: 0.4348 - val_accuracy: 0.8507 - val_loss: 0.4218
# Epoch 347/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8406 - loss: 0.4579 - val_accuracy: 0.8492 - val_loss: 0.4223
# Epoch 348/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8491 - loss: 0.4312 - val_accuracy: 0.8513 - val_loss: 0.4220
# Epoch 349/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8378 - loss: 0.4543 - val_accuracy: 0.8507 - val_loss: 0.4207
# Epoch 350/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8405 - loss: 0.4490 - val_accuracy: 0.8498 - val_loss: 0.4226
# Epoch 351/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8426 - loss: 0.4386 - val_accuracy: 0.8518 - val_loss: 0.4158
# Epoch 352/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8436 - loss: 0.4492 - val_accuracy: 0.8507 - val_loss: 0.4211
# Epoch 353/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8367 - loss: 0.4561 - val_accuracy: 0.8503 - val_loss: 0.4214
# Epoch 354/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8387 - loss: 0.4521 - val_accuracy: 0.8526 - val_loss: 0.4147
# Epoch 355/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8390 - loss: 0.4456 - val_accuracy: 0.8539 - val_loss: 0.4124
# Epoch 356/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8334 - loss: 0.4617 - val_accuracy: 0.8509 - val_loss: 0.4234
# Epoch 357/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8463 - loss: 0.4387 - val_accuracy: 0.8496 - val_loss: 0.4217
# Epoch 358/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8446 - loss: 0.4412 - val_accuracy: 0.8529 - val_loss: 0.4164
# Epoch 359/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8411 - loss: 0.4461 - val_accuracy: 0.8513 - val_loss: 0.4180
# Epoch 360/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8453 - loss: 0.4454 - val_accuracy: 0.8526 - val_loss: 0.4177
# Epoch 361/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8436 - loss: 0.4402 - val_accuracy: 0.8533 - val_loss: 0.4143
# Epoch 362/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8421 - loss: 0.4404 - val_accuracy: 0.8513 - val_loss: 0.4212
# Epoch 363/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8387 - loss: 0.4452 - val_accuracy: 0.8524 - val_loss: 0.4162
# Epoch 364/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8381 - loss: 0.4563 - val_accuracy: 0.8526 - val_loss: 0.4186
# Epoch 365/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8430 - loss: 0.4513 - val_accuracy: 0.8522 - val_loss: 0.4178
# Epoch 366/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8429 - loss: 0.4395 - val_accuracy: 0.8533 - val_loss: 0.4187
# Epoch 367/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8409 - loss: 0.4499 - val_accuracy: 0.8529 - val_loss: 0.4160
# Epoch 368/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8456 - loss: 0.4418 - val_accuracy: 0.8520 - val_loss: 0.4209
# Epoch 369/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8446 - loss: 0.4448 - val_accuracy: 0.8533 - val_loss: 0.4190
# Epoch 370/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8475 - loss: 0.4373 - val_accuracy: 0.8518 - val_loss: 0.4164
# ...
# Epoch 478/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8503 - loss: 0.4190 - val_accuracy: 0.8557 - val_loss: 0.4160
# Epoch 479/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8564 - loss: 0.4115 - val_accuracy: 0.8563 - val_loss: 0.4153
# Epoch 480/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8492 - loss: 0.4211 - val_accuracy: 0.8563 - val_loss: 0.4158
# Epoch 481/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8556 - loss: 0.4208 - val_accuracy: 0.8594 - val_loss: 0.4073
# Epoch 482/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8542 - loss: 0.4092 - val_accuracy: 0.8594 - val_loss: 0.4084
# Epoch 483/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8532 - loss: 0.4171 - val_accuracy: 0.8576 - val_loss: 0.4126
# Epoch 484/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8525 - loss: 0.4177 - val_accuracy: 0.8596 - val_loss: 0.4075
# Epoch 485/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8565 - loss: 0.4145 - val_accuracy: 0.8583 - val_loss: 0.4118
# Epoch 486/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8546 - loss: 0.4110 - val_accuracy: 0.8594 - val_loss: 0.4071
# Epoch 487/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8611 - loss: 0.4019 - val_accuracy: 0.8594 - val_loss: 0.4111
# Epoch 488/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8556 - loss: 0.4087 - val_accuracy: 0.8561 - val_loss: 0.4157
# Epoch 489/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8597 - loss: 0.4164 - val_accuracy: 0.8592 - val_loss: 0.4101
# Epoch 490/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8527 - loss: 0.4100 - val_accuracy: 0.8589 - val_loss: 0.4095
# Epoch 491/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8572 - loss: 0.4044 - val_accuracy: 0.8585 - val_loss: 0.4115
# Epoch 492/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8525 - loss: 0.4231 - val_accuracy: 0.8587 - val_loss: 0.4109
# Epoch 493/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8547 - loss: 0.4132 - val_accuracy: 0.8576 - val_loss: 0.4134
# Epoch 494/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8613 - loss: 0.4035 - val_accuracy: 0.8602 - val_loss: 0.4059
# Epoch 495/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8561 - loss: 0.4225 - val_accuracy: 0.8589 - val_loss: 0.4097
# Epoch 496/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8536 - loss: 0.4091 - val_accuracy: 0.8585 - val_loss: 0.4121
# Epoch 497/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8605 - loss: 0.3972 - val_accuracy: 0.8585 - val_loss: 0.4112
# Epoch 498/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8567 - loss: 0.4088 - val_accuracy: 0.8609 - val_loss: 0.4062
# Epoch 499/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8540 - loss: 0.4186 - val_accuracy: 0.8570 - val_loss: 0.4152
# Epoch 500/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8558 - loss: 0.4144 - val_accuracy: 0.8546 - val_loss: 0.4171
# Epoch 501/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8561 - loss: 0.4140 - val_accuracy: 0.8581 - val_loss: 0.4100
# Epoch 502/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8522 - loss: 0.4197 - val_accuracy: 0.8583 - val_loss: 0.4117
# Epoch 503/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8564 - loss: 0.3948 - val_accuracy: 0.8576 - val_loss: 0.4149
# Epoch 504/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8483 - loss: 0.4211 - val_accuracy: 0.8596 - val_loss: 0.4081
# Epoch 505/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8559 - loss: 0.4069 - val_accuracy: 0.8579 - val_loss: 0.4156
# Epoch 506/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8542 - loss: 0.4099 - val_accuracy: 0.8589 - val_loss: 0.4124
# Epoch 507/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8542 - loss: 0.4070 - val_accuracy: 0.8594 - val_loss: 0.4103
# Epoch 508/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8600 - loss: 0.3983 - val_accuracy: 0.8589 - val_loss: 0.4125
# Epoch 509/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8494 - loss: 0.4219 - val_accuracy: 0.8566 - val_loss: 0.4193
# Epoch 510/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8537 - loss: 0.4204 - val_accuracy: 0.8570 - val_loss: 0.4167
# Epoch 511/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8578 - loss: 0.3999 - val_accuracy: 0.8589 - val_loss: 0.4116
# Epoch 512/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8581 - loss: 0.4099 - val_accuracy: 0.8581 - val_loss: 0.4153
# Epoch 513/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8575 - loss: 0.4037 - val_accuracy: 0.8587 - val_loss: 0.4084
# Epoch 514/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8590 - loss: 0.4143 - val_accuracy: 0.8537 - val_loss: 0.4235
# Epoch 515/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8631 - loss: 0.4091 - val_accuracy: 0.8568 - val_loss: 0.4157
# Epoch 516/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8569 - loss: 0.4010 - val_accuracy: 0.8587 - val_loss: 0.4117
# Epoch 517/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8538 - loss: 0.4117 - val_accuracy: 0.8598 - val_loss: 0.4059
# Epoch 518/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8584 - loss: 0.4050 - val_accuracy: 0.8592 - val_loss: 0.4071
# Epoch 519/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8556 - loss: 0.4149 - val_accuracy: 0.8596 - val_loss: 0.4073
# Epoch 520/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8496 - loss: 0.4155 - val_accuracy: 0.8585 - val_loss: 0.4033
# Epoch 521/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8555 - loss: 0.4109 - val_accuracy: 0.8579 - val_loss: 0.4102
# Epoch 522/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8540 - loss: 0.4082 - val_accuracy: 0.8589 - val_loss: 0.4107
# Epoch 523/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8567 - loss: 0.4122 - val_accuracy: 0.8592 - val_loss: 0.4106
# Epoch 524/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8591 - loss: 0.3996 - val_accuracy: 0.8609 - val_loss: 0.4073
# Epoch 525/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8556 - loss: 0.3992 - val_accuracy: 0.8600 - val_loss: 0.4110
# Epoch 526/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8629 - loss: 0.3956 - val_accuracy: 0.8609 - val_loss: 0.4072
# Epoch 527/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8552 - loss: 0.4178 - val_accuracy: 0.8568 - val_loss: 0.4194
# Epoch 528/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8599 - loss: 0.4062 - val_accuracy: 0.8594 - val_loss: 0.4127
# Epoch 529/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8559 - loss: 0.4073 - val_accuracy: 0.8600 - val_loss: 0.4093
# Epoch 530/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8613 - loss: 0.3997 - val_accuracy: 0.8600 - val_loss: 0.4079
# Epoch 531/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8536 - loss: 0.4213 - val_accuracy: 0.8618 - val_loss: 0.4065
# Epoch 532/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8568 - loss: 0.4089 - val_accuracy: 0.8600 - val_loss: 0.4101
# Epoch 533/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8563 - loss: 0.4118 - val_accuracy: 0.8607 - val_loss: 0.4090
# Epoch 534/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8581 - loss: 0.4105 - val_accuracy: 0.8622 - val_loss: 0.4077
# Epoch 535/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8645 - loss: 0.3990 - val_accuracy: 0.8607 - val_loss: 0.4069
# Epoch 536/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8527 - loss: 0.4161 - val_accuracy: 0.8600 - val_loss: 0.4100
# Epoch 537/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8606 - loss: 0.4058 - val_accuracy: 0.8609 - val_loss: 0.4092
# Epoch 538/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8612 - loss: 0.3966 - val_accuracy: 0.8592 - val_loss: 0.4131
# Epoch 539/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8542 - loss: 0.4179 - val_accuracy: 0.8605 - val_loss: 0.4122
# Epoch 540/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8546 - loss: 0.4092 - val_accuracy: 0.8598 - val_loss: 0.4121
# Epoch 541/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8614 - loss: 0.4007 - val_accuracy: 0.8618 - val_loss: 0.4079
# Epoch 542/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8588 - loss: 0.4151 - val_accuracy: 0.8574 - val_loss: 0.4141
# Epoch 543/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8575 - loss: 0.4117 - val_accuracy: 0.8587 - val_loss: 0.4144
# Epoch 544/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8574 - loss: 0.4072 - val_accuracy: 0.8620 - val_loss: 0.4059
# Epoch 545/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8616 - loss: 0.3980 - val_accuracy: 0.8609 - val_loss: 0.4068
# Epoch 546/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8532 - loss: 0.4054 - val_accuracy: 0.8570 - val_loss: 0.4184
# Epoch 547/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8572 - loss: 0.4129 - val_accuracy: 0.8585 - val_loss: 0.4146
# Epoch 548/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8568 - loss: 0.4081 - val_accuracy: 0.8596 - val_loss: 0.4101
# Epoch 549/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8562 - loss: 0.4073 - val_accuracy: 0.8609 - val_loss: 0.4098
# Epoch 550/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8549 - loss: 0.4034 - val_accuracy: 0.8613 - val_loss: 0.4074
# Epoch 551/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8545 - loss: 0.4086 - val_accuracy: 0.8598 - val_loss: 0.4089
# Epoch 552/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8592 - loss: 0.4053 - val_accuracy: 0.8611 - val_loss: 0.4085
# Epoch 553/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8658 - loss: 0.3890 - val_accuracy: 0.8592 - val_loss: 0.4134
# Epoch 554/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8551 - loss: 0.4046 - val_accuracy: 0.8596 - val_loss: 0.4118
# Epoch 555/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8556 - loss: 0.4036 - val_accuracy: 0.8605 - val_loss: 0.4124
# Epoch 556/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8721 - loss: 0.3897 - val_accuracy: 0.8592 - val_loss: 0.4112
# Epoch 557/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8616 - loss: 0.3912 - val_accuracy: 0.8613 - val_loss: 0.4066
# Epoch 558/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8565 - loss: 0.4080 - val_accuracy: 0.8609 - val_loss: 0.4036
# Epoch 559/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8598 - loss: 0.4037 - val_accuracy: 0.8613 - val_loss: 0.4117
# Epoch 560/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8563 - loss: 0.4166 - val_accuracy: 0.8605 - val_loss: 0.4109
# Epoch 561/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8586 - loss: 0.4059 - val_accuracy: 0.8600 - val_loss: 0.4101
# Epoch 562/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8571 - loss: 0.4112 - val_accuracy: 0.8615 - val_loss: 0.4075
# Epoch 563/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8635 - loss: 0.3932 - val_accuracy: 0.8609 - val_loss: 0.4104
# Epoch 564/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8607 - loss: 0.3992 - val_accuracy: 0.8596 - val_loss: 0.4105
# Epoch 565/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8600 - loss: 0.4066 - val_accuracy: 0.8594 - val_loss: 0.4116
# Epoch 566/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8611 - loss: 0.4000 - val_accuracy: 0.8618 - val_loss: 0.4067
# Epoch 567/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8641 - loss: 0.3962 - val_accuracy: 0.8611 - val_loss: 0.4061
# Epoch 568/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8619 - loss: 0.3923 - val_accuracy: 0.8607 - val_loss: 0.4047
# Epoch 569/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8587 - loss: 0.4014 - val_accuracy: 0.8622 - val_loss: 0.4053
# Epoch 570/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8614 - loss: 0.3901 - val_accuracy: 0.8635 - val_loss: 0.4082
# Epoch 571/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8593 - loss: 0.4000 - val_accuracy: 0.8609 - val_loss: 0.4088
# Epoch 572/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8571 - loss: 0.4097 - val_accuracy: 0.8622 - val_loss: 0.4058
# Epoch 573/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8569 - loss: 0.4122 - val_accuracy: 0.8607 - val_loss: 0.4095
# Epoch 574/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8665 - loss: 0.3987 - val_accuracy: 0.8611 - val_loss: 0.4025
# Epoch 575/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8615 - loss: 0.3956 - val_accuracy: 0.8607 - val_loss: 0.4126
# Epoch 576/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8542 - loss: 0.4144 - val_accuracy: 0.8626 - val_loss: 0.4070
# Epoch 577/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8600 - loss: 0.3975 - val_accuracy: 0.8637 - val_loss: 0.4053
# Epoch 578/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8598 - loss: 0.4044 - val_accuracy: 0.8624 - val_loss: 0.4065
# Epoch 579/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8571 - loss: 0.4018 - val_accuracy: 0.8598 - val_loss: 0.4050
# Epoch 580/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8588 - loss: 0.4079 - val_accuracy: 0.8635 - val_loss: 0.4030
# Epoch 581/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8693 - loss: 0.3920 - val_accuracy: 0.8605 - val_loss: 0.4033
# Epoch 582/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8629 - loss: 0.3988 - val_accuracy: 0.8602 - val_loss: 0.4106
# Epoch 583/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8563 - loss: 0.3994 - val_accuracy: 0.8620 - val_loss: 0.4071
# Epoch 584/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8676 - loss: 0.3836 - val_accuracy: 0.8622 - val_loss: 0.4037
# Epoch 585/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8656 - loss: 0.3878 - val_accuracy: 0.8620 - val_loss: 0.4123
# Epoch 586/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8571 - loss: 0.4031 - val_accuracy: 0.8613 - val_loss: 0.4057
# Epoch 587/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8601 - loss: 0.3972 - val_accuracy: 0.8611 - val_loss: 0.4103
# Epoch 588/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8561 - loss: 0.4051 - val_accuracy: 0.8622 - val_loss: 0.4095
# Epoch 589/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8631 - loss: 0.3907 - val_accuracy: 0.8596 - val_loss: 0.4128
# Epoch 590/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8653 - loss: 0.3883 - val_accuracy: 0.8618 - val_loss: 0.4025
# Epoch 591/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8592 - loss: 0.4011 - val_accuracy: 0.8613 - val_loss: 0.4103
# Epoch 592/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8589 - loss: 0.4028 - val_accuracy: 0.8628 - val_loss: 0.4041
# Epoch 593/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8576 - loss: 0.4005 - val_accuracy: 0.8605 - val_loss: 0.3997
# Epoch 594/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8526 - loss: 0.4044 - val_accuracy: 0.8615 - val_loss: 0.4033
# Epoch 595/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8597 - loss: 0.3973 - val_accuracy: 0.8637 - val_loss: 0.4046
# Epoch 596/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8672 - loss: 0.3835 - val_accuracy: 0.8594 - val_loss: 0.4179
# Epoch 597/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8668 - loss: 0.3940 - val_accuracy: 0.8622 - val_loss: 0.4064
# Epoch 598/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8660 - loss: 0.3903 - val_accuracy: 0.8611 - val_loss: 0.4077
# Epoch 599/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8667 - loss: 0.3830 - val_accuracy: 0.8618 - val_loss: 0.4095
# Epoch 600/600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8573 - loss: 0.4015 - val_accuracy: 0.8639 - val_loss: 0.4061

# %%
(end - start)/ 60
# Out:
# 11.821180283983331

# %%
acc_train = hist.history['accuracy']
acc_test = hist.history['val_accuracy']
loss_train = hist.history['loss']
loss_test = hist.history['val_loss']

plt.axes().set_facecolor('gray')
plt.grid('True')


plt.plot(loss_train, color='green', label='Train loss')
plt.plot(loss_test, color='yellow', label='Test loss')
plt.plot(acc_train, color='blue', label='Train acc')
plt.plot(acc_test, color='red', label='Test acc')


plt.show()

# %%
acc_train = hist.history['accuracy']
acc_test = hist.history['val_accuracy']

plt.axes().set_facecolor('gray')
plt.grid('True')


plt.plot(acc_train, color='blue', label='Train acc');
plt.plot(acc_test, color='red', label='Test acc');

# %%
loss_train = hist.history['loss']
loss_test = hist.history['val_loss']

plt.axes().set_facecolor('gray')
plt.grid('True')


plt.plot(loss_train, color='blue', label='Train loss');
plt.plot(loss_test, color='red', label='Test loss');

# %%
y_pred_train = model_cnn.predict(x_train)
y_pred_test = model_cnn.predict(x_test)


index_train = random.randint(0, 9198)
print(f'y_train: {y_train[index_train]} y_pred_train:{y_pred_train[index_train]}')

index_test = random.randint(0, 3942)
print(f'y_test: {y_test[index_test]} y_pred_test:{y_pred_test[index_test]}')
# Out:
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# y_train: 0 y_pred_train:[0.97562873 0.01976957 0.00460169]
# y_test: 0 y_pred_test:[0.97592145 0.01952904 0.00454956]

# %%
y_pred_train_smax = softmax(y_pred_train, axis=1)
y_pred_test_smax = softmax(y_pred_test, axis=1)

y_pred_train_smax = np.argmax(y_pred_train_smax, axis=1)
y_pred_test_smax = np.argmax(y_pred_test_smax, axis=1)


y_pred_test_smax.shape, y_pred_train_smax.shape
# Out:
# ((4608,), (10750,))

# %%
print(f'y_train: {y_train[index_train]} y_pred_train:{y_pred_train_smax[index_train]}')

index_test = random.randint(0, 3948)
print(f'y_test: {y_test[index_test]} y_pred_test:{y_pred_test_smax[index_test]}')
# Out:
# y_train: 0 y_pred_train:0
# y_test: 1 y_pred_test:1

# %%
acc_train = accuracy_score(y_train, y_pred_train_smax)
acc_test = accuracy_score(y_test, y_pred_test_smax)

p = precision_score(y_test, y_pred_test_smax, average='micro')
r = recall_score(y_test, y_pred_test_smax, average='micro')


print(f'Acc Train: {acc_train} - Acc Test: {acc_test} - Percision: {p} - Recall: {r}')
# Out:
# Acc Train: 0.876 - Acc Test: 0.8604600694444444 - Percision: 0.8604600694444444 - Recall: 0.8604600694444444

# %%
model_cnn.evaluate(x=x_test, y=y_test)
model_cnn.evaluate(x=x_train, y=y_train)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8507 - loss: 0.4180
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8711 - loss: 0.3730
# [0.36163538694381714, 0.8759999871253967]

# %%
cm_train = confusion_matrix(y_true=y_train, y_pred=y_pred_train_smax)
disp_cm_train = ConfusionMatrixDisplay(cm_train)

cm_train = cm_train.astype('float') / cm_train.sum(axis=1)[:, np.newaxis]
disp_cm_train_perce = ConfusionMatrixDisplay(cm_train)


fig , (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.set_title('Values')
ax2.set_title('Percentage')
disp_cm_train.plot(ax=ax1);
disp_cm_train_perce.plot(ax=ax2);

# %%
cm_test = confusion_matrix(y_true=y_test, y_pred=y_pred_test_smax)
disp_cm_test = ConfusionMatrixDisplay(cm_test)

cm_test = cm_test.astype('float') / cm_test.sum(axis=1)[:, np.newaxis]
disp_cm_test_perce = ConfusionMatrixDisplay(cm_test)


fig , (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.set_title('Values')
ax2.set_title('Percentage')
disp_cm_test.plot(ax=ax1);
disp_cm_test_perce.plot(ax=ax2);
